# %% [markdown]
# # Automatic Google search of venue images

# %%
CITY = 'LAS VEGAS'

# %%
# !pip install google_images_download
# Out:
# Collecting google_images_download
#   Downloading https://files.pythonhosted.org/packages/18/ed/0319d30c48f3653802da8e6dcfefcea6370157d10d566ef6807cceb5ec4d/google_images_download-2.8.0.tar.gz
# Collecting selenium
#   Downloading https://files.pythonhosted.org/packages/80/d6/4294f0b4bce4de0abf13e17190289f9d0613b0a44e5dd6a7f5ca98459853/selenium-3.141.0-py2.py3-none-any.whl (904kB)
#      |████████████████████████████████| 911kB 43.1MB/s
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.6/dist-packages (from selenium->google_images_download) (1.24.3)
# Building wheels for collected packages: google-images-download
#   Building wheel for google-images-download (setup.py) ... done
#   Created wheel for google-images-download: filename=google_images_download-2.8.0-py2.py3-none-any.whl size=14550 sha256=615fea0fd5794fb6dec341c77dd4807c518b8de83e8cda10847f5daddf7c897a
#   Stored in directory: /root/.cache/pip/wheels/1f/28/ad/f56e7061e1d2a9a1affe2f9c649c2570cb9198dd24ede0bbab
# Successfully built google-images-download
# Installing collected packages: selenium, google-images-download
# Successfully installed google-images-download-2.8.0 selenium-3.141.0

# %%
import pandas as pd
import numpy as np
from google_images_download import google_images_download

# %%
import nltk
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# True

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-768cad41-8c41-46d0-9bbd-f0f594345438" name="files[]" multiple disabled />
#      <output id="result-768cad41-8c41-46d0-9bbd-f0f594345438">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving predicthq_export - Las Vegas - Ralph Lauren.csv to predicthq_export - Las Vegas - Ralph Lauren.csv

# %%
events = pd.read_csv("predicthq_export - Las Vegas - Ralph Lauren.csv")

# %%
events.head(5)
# Out:
#                    id  ...            first_seen
# 0  QMkyB7YCXgZQqsWB8e  ...  2017-12-26T08:03:43Z
# 1        nvABpR9LXwwk  ...  2016-09-04T00:02:42Z
# 2        PlVJdqVPJzXm  ...  2016-08-03T03:38:16Z
# 3        1KA12OQWR3pl  ...  2017-07-28T00:53:30Z
# 4  TA5fR5zPt5VCF6H3JY  ...  2019-09-11T23:20:23Z
#
# [5 rows x 20 columns]

# %%
events.shape
# Out:
# (99076, 20)

# %%
events.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99076 entries, 0 to 99075
# Data columns (total 20 columns):
# id                         99076 non-null object
# title                      99076 non-null object
# description                30641 non-null object
# start                      99076 non-null object
# end                        99076 non-null object
# predicted_end              730 non-null object
# duration                   99076 non-null int64
# labels                     99076 non-null object
# category                   99076 non-null object
# timezone                   98106 non-null object
# country                    99076 non-null object
# location                   99076 non-null object
# venue_name                 91581 non-null object
# venue_formatted_address    90328 non-null object
# scope                      99076 non-null object
# rank                       99076 non-null int64
# local_rank                 97422 non-null float64
# aviation_rank              44424 non-null float64
# state                      99076 non-null object
# first_seen                 99075 non-null object
# dtypes: float64(2), int64(2), object(16)
# memory usage: 15.1+ MB

# %%
events['venue_id'] = events.groupby('venue_name').ngroup()
events.head(2)
# Out:
#                    id  ... venue_id
# 0  QMkyB7YCXgZQqsWB8e  ...      944
# 1        nvABpR9LXwwk  ...       -1
#
# [2 rows x 21 columns]

# %%
events.venue_id.nunique()
# Out:
# 1268

# %%
venue = pd.DataFrame(events[['venue_name', 'venue_id']].drop_duplicates(['venue_id']).dropna())
venue['venue_type'] = ''

# %%
len(venue)
# Out:
# 1267

# %%
venue.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1267 entries, 0 to 99006
# Data columns (total 3 columns):
# venue_name    1267 non-null object
# venue_id      1267 non-null int64
# venue_type    1267 non-null object
# dtypes: int64(1), object(2)
# memory usage: 39.6+ KB

# %%
venue[venue['venue_name'].str.contains(',')]
# Out:
#                                               venue_name  venue_id venue_type
# 43                Viva ELVIS Theater, Aria at CityCenter      1146
# 67                       South Point Hotel, Casino & Spa       939
# 161                     Crown Theater and Nightclub, Rio       243
# 5496     bounty hunter 415 East Windmill Lane, Las Vegas      1263
# 8082            The Westin Las Vegas Hotel, Casino & Spa      1075
# 13916             University of Nevada, Las Vegas (UNLV)      1122
# 14703  University of Nevada, Las Vegas: Alta Ham Fine...      1124
# 20167                                    Congo Room, The       213
# 20766                    University of Nevada, Las Vegas      1121
# 22873          SLS Las Vegas, a Tribute Portfolio Resort       894
# 39412                       Mandarin Oriental, Las Vegas       680
# 43556  Dignity Health - St. Rose Dominican, San Marti...       274
# 47038                           Capstone Brokerage, Inc.       155
# 52245                   WEICHERT, REALTORS® - Millennium      1150
# 52865                 Bandito Latin Kitchen and Cantina,        89
# 52874                                     Las Vegas, USA       634
# 55785  University of Nevada, Las Vegas, Ham Fine Arts...      1123
# 59290                         Officer's Club, Nellis AFB       776
# 60579  Tuscany Suites & Casino,Florentine Ballroom an...      1107
# 60672  Encore Las Vegas 3131 S Las Vegas Blvd Las Veg...       326
# 61051  Miller Lite Conciertos Originales - Las Vegas, NV       701
# 78299                Las Vegas, NV - City National Arena       633
# 81135  Police, Fire, EMS, and Municipal Employee Pens...       832
# 93373               Tropicana Las Vegas, Cohiba Ballroom      1102
# 95266  South Point Hotel, Casino & Spa - Exhibit Hall...       940

# %%
# events.to_csv('venue.csv', columns=['venue_name'], index=False)
# Replace ',' with ' ' for search by keywords, which requires separation
# of keywords by ','
venue['new_venue_name'] = venue['venue_name'].str.replace(',', ' ')
venue_name = venue['new_venue_name'].str.cat(sep=',')

# %%
venue.head(3)
# Out:
#                                venue_name  ...                          new_venue_name
# 0    Spa Ravella at Hilton Lake Las Vegas  ...    Spa Ravella at Hilton Lake Las Vegas
# 2  Green Valley Ranch Resort Spa & Casino  ...  Green Valley Ranch Resort Spa & Casino
# 3             Las Vegas Convention Center  ...             Las Vegas Convention Center
#
# [3 rows x 4 columns]

# %%
len(venue_name.split(','))
# Out:
# 1267

# %%
import pathlib
import shutil
import os

# Remove directories if exist
image_dir = pathlib.Path('/content/downloads')
if os.path.isdir(image_dir):
  shutil.rmtree(image_dir)

# %%
# Class instantiation
response = google_images_download.googleimagesdownload()   

# Create dictionary of arguments
arguments = {"keywords":venue_name, 
            #  "usage_rights":"labeled-for-reuse-with-modifications",
             "limit":1,
             "format":"jpg",
             "color_type":"full-color",
             "type":"photo",
             "size":"medium",
             "silent_mode":True
             }   
paths = response.download(arguments)
# Out:
# Downloading images for: Spa Ravella at Hilton Lake Las Vegas ...
# Downloading images for: Green Valley Ranch Resort Spa & Casino ...
# Downloading images for: Las Vegas Convention Center ...
# Downloading images for: Henderson Convention Center ...
# Downloading images for: Night Owl Showroom ...
# Downloading images for: Leif Erikson Day ...
# Downloading images for: Hooters Casino Hotel ...
# Downloading images for: World Post Day ...
# Downloading images for: Hispanic Museum of Nevada ...
# Downloading images for: V Theater ...
# Downloading images for: Flamingo Las Vegas ...
# Downloading images for: Bally's Las Vegas Hotel & Casino ...
# Downloading images for: Tommy Wind Theater and Events Center ...
# Downloading images for: Henderson Pavilion ...
# Downloading images for: Tournament of Kings ...
# Downloading images for: Brooklyn Bowl Las Vegas ...
# Downloading images for: Sam's Town Hotel & Gambling Hall ...
# Downloading images for: Stratosphere Las Vegas ...
# Downloading images for: Improv Comedy Club -  Harrah's Hotel ...
# Downloading images for: Jokesters Comedy Club ...
# Downloading images for: Jabbawockeez Theater at MGM Grand ...
# Downloading images for: House of Blues Las Vegas ...
# Downloading images for: Bellagio - O Theater ...
# Downloading images for: The Smith Center ...
# Downloading images for: T-Mobile Arena ...
# Downloading images for: Luxor Las Vegas ...
# Downloading images for: The Linq Hotel & Casino ...
# Downloading images for: Stoney's Rockin' Country ...
# Downloading images for: Viva ELVIS Theater  Aria at CityCenter ...
# Downloading images for: New York-New York Hotel & Casino ...
# Downloading images for: Le Theatre des Arts at Paris Las Vegas ...
# Downloading images for: The Venetian Resort ...
# Downloading images for: Cannery Casino & Hotel ...
# Downloading images for: Mandalay Bay ...
# Downloading images for: KA Theatre at MGM Grand Hotel and Casino ...
# Downloading images for: Wynn Las Vegas ...
# Downloading images for: Westgate Las Vegas Resort & Casino ...
# Downloading images for: The Mirage ...
# Downloading images for: MGM Grand ...
# Downloading images for: Hard Rock Hotel & Casino - The Joint ...
# Downloading images for: Golden Nugget Hotel & Casino ...
# Downloading images for: Rio All-Suites Hotel and Casino ...
# Downloading images for: Caesars Palace ...
# Downloading images for: South Point Hotel  Casino & Spa ...
# Downloading images for: The Mirage- Terry Fator Theatre ...
# Downloading images for: Las Vegas Club Hotel & Casino ...
# Downloading images for: Tuscany Suites & Casino ...
# Downloading images for: Larry Flynt's Hustler Club ...
# Downloading images for: Las Vegas Country Saloon ...
# Downloading images for: The Foundry at SLS ...
# Downloading images for: Tropicana Hotel & Casino ...
# Downloading images for: Hard Rock Live ...
# Downloading images for: Count's Vamp'd Rock Bar & Grill ...
# Downloading images for: Itsy Bitsy ...
# Downloading images for: The Axis Theater Las Vegas Planet Hollywood ...
# Downloading images for: The Orleans Hotel & Casino ...
# Downloading images for: Backstage & Billiards Lounge ...
# Downloading images for: Suncoast Hotel & Casino ...
# Downloading images for: Chippendales Theatre ...
# Downloading images for: Palms Casino Resort - Rain Nightclub ...
# Downloading images for: Eiffel Tower Viewing Deck at Paris Las Vegas ...
# Downloading images for: Binion's Hotel & Casino ...
# Downloading images for: The Dillinger ...
# Downloading images for: Mickie Finnz ...
# Downloading images for: Sin City Theatre ...
# Downloading images for: Money Plays ...
# Downloading images for: Cosmopolitan of Las Vegas ...
# Downloading images for: Sands Showroom at the Venetian ...
# Downloading images for: Anthony Cools Experience ...
# Downloading images for: Excalibur Hotel & Casino ...
# Downloading images for: Penn & Teller Theater ...
# Downloading images for: David Copperfield ...
# Downloading images for: XS Nightclub - Wynn Las Vegas ...
# Downloading images for: Drai's Beachclub and Nightclub ...
# Downloading images for: Intrigue Nightclub - Wynn Las Vegas ...
# Downloading images for: Brad Garret's Comedy Club ...
# Downloading images for: Margaritaville Restaurant Las Vegas ...
# Downloading images for: Crown Theater and Nightclub  Rio ...
# Downloading images for: The Light Vegas ...
# Downloading images for: Sunset Park ...
# Downloading images for: Wet Republic Ultra Pool ...
# Downloading images for: Encore Beach Club ...
# Downloading images for: Cosmopolitan of Las Vegas - Marquee Nightclub & Dayclub ...
# Downloading images for: Sahara West Library ...
# Downloading images for: DAYLIGHT Beach Club ...
# Downloading images for: Cabaret Jazz - Smith Center for the Performing Arts ...
# Downloading images for: Hard Rock Hotel & Casino ...
# Downloading images for: Hennessey's Tavern ...
# Downloading images for: Clark County Government Center Amphitheater ...
# Downloading images for: Spring Valley Library ...
# Downloading images for: World Mental Health Day ...
# Downloading images for: Dussehra ...
# Downloading images for: Windows Theatre ...
# Downloading images for: Harrah's Las Vegas Hotel & Casino ...
# Downloading images for: Westgate Cabaret at Westgate Las Vegas Resort and Casino ...
# Downloading images for: The Dive Bar ...
# Downloading images for: Tacos & Beer ...
# Downloading images for: ARIA Resort & Casino ...
# Downloading images for: International Day of the Girl Child ...
# Downloading images for: Saxe Theater ...
# Downloading images for: Tao Nightclub ...
# Downloading images for: Scoundrels Pub ...
# Downloading images for: Treasure Island ...
# Downloading images for: Centennial Hills Library ...
# Downloading images for: Oquendo Center ...
# Downloading images for: Windmill Library ...
# Downloading images for: West Las Vegas Library ...
# Downloading images for: International Day for Natural Disaster Reduction ...
# Downloading images for: Mezzo Bistro and Wine ...
# Downloading images for: Encore Theater at Wynn Las Vegas ...
# Downloading images for: Bunkhouse Saloon ...
# Downloading images for: CIRQUE DU SOLEIL - HARTFORD ...
# Downloading images for: Caesars Palace - Omnia Nightclub ...
# Downloading images for: Henderson District - Paseo Verde Library ...
# Downloading images for: Navy Birthday ...
# Downloading images for: World Sight Day ...
# Downloading images for: The Las Vegas National Golf Club ...
# Downloading images for: Harrah's Showroom at Harrah's Las Vegas ...
# Downloading images for: Paris Las Vegas ...
# Downloading images for: TCMI Christian Event Center ...
# Downloading images for: Las Vegas Clark County Library ...
# Downloading images for: The Venetian Resort - Venetian Theatre ...
# Downloading images for: The Venetian - The Palazzo ...
# Downloading images for: Mandalay Bay Convention Center ...
# Downloading images for: 133 S Water Street ...
# Downloading images for: Aliante Casino + Hotel + Spa ...
# Downloading images for: Classic Jewel ...
# Downloading images for: Palms Casino Resort ...
# Downloading images for: Pole Fitness Studio ...
# Downloading images for: International Day of Rural Women ...
# Downloading images for: White Cane Safety Day ...
# Downloading images for: McCarran International Airport ...
# Downloading images for: Eagle Aerie Hall ...
# Downloading images for: Love Theatre at The Mirage Hotel and Casino ...
# Downloading images for: The Sand Dollar Lounge ...
# Downloading images for: Mandalay Bay Events Center ...
# Downloading images for: Mirage Hotel & Casino - Terry Fator Theatre ...
# Downloading images for: The Yard at TopGolf ...
# Downloading images for: The Smith Center for the Performing Arts - Reynolds Hall ...
# Downloading images for: Red Rock Casino Resort & Spa ...
# Downloading images for: Kracker Boxx Bar ...
# Downloading images for: Surrender Nightclub ...
# Downloading images for: Northwest Career & Technical Academy ...
# Downloading images for: Craig Ranch Regional Park ...
# Downloading images for: University of Phoenix - Las Vegas Campus ...
# Downloading images for: Unitarian Universalist Congregation of Las Vegas ...
# Downloading images for: Cashman Center ...
# Downloading images for: Anthem Center Sun City Anthem ...
# Downloading images for: Summerlin Library ...
# Downloading images for: V3 Theater at Planet Hollywood Resort and Casino ...
# Downloading images for: World Food Day ...
# Downloading images for: Sam Boyd Stadium ...
# Downloading images for: Container Park ...
# Downloading images for: M Resort Spa Casino ...
# Downloading images for: Regal Cinemas Sunset Station 13 & IMAX ...
# Downloading images for: The Colosseum ...
# Downloading images for: Eastside Cannery Casino Hotel ...
# Downloading images for: MGM Grand Garden Arena ...
# Downloading images for: Adrenaline Sports Bar & Grill ...
# Downloading images for: Hard Rock Hotel & Casino - Vinyl ...
# Downloading images for: Boulder Station Hotel & Casino ...
# Downloading images for: First Day of Sukkot ...
# Downloading images for: Boss's Day ...
# Downloading images for: International Day for the Eradication of Poverty ...
# Downloading images for: Orleans Showroom ...
# Downloading images for: Workforce Connections - One Stop Career Center ...
# Downloading images for: Bellagio Hotel and Casino ...
# Downloading images for: Toby Keith's I Love This Bar & Grill ...
# Downloading images for: ABC Kids Expo ...
# Downloading images for: Copper Cat Studio ...
# Downloading images for: Gold Coast Hotel and Casino ...
# Downloading images for: Vic & Anthony's ...
# Downloading images for: Michael Jackson ONE ...
# Downloading images for: Vanguard Lounge ...
# Downloading images for: Palace Station Hotel & Casino ...
# Downloading images for: Le Reve Theater at Wynn Las Vegas ...
# Downloading images for: Event Center Las Vegas ...
# Downloading images for: Hope Church ...
# Downloading images for: Erotic Heritage Museum ...
# Downloading images for: Last Day of Sukkot ...
# Downloading images for: Texas Station ...
# Downloading images for: Hakkasan Las Vegas Nightclub ...
# Downloading images for: IBM Insight ...
# Downloading images for: Planet Hollywood Resort & Casino ...
# Downloading images for: North Las Vegas Airport ...
# Downloading images for: World Development Information Day ...
# Downloading images for: United Nations Day ...
# Downloading images for: Shmini Atzeret ...
# Downloading images for: Simchat Torah ...
# Downloading images for: SpringHill Suites by Marriott Las Vegas Convention Center ...
# Downloading images for: Springs Preserve ...
# Downloading images for: Green Valley Library ...
# Downloading images for: World Market Center Las Vegas ...
# Downloading images for: World Day for Audiovisual Heritage ...
# Downloading images for: Cosmopolitan of Las Vegas - STK ...
# Downloading images for: Summerlin Hospital ...
# Downloading images for: Circus Circus Las Vegas ...
# Downloading images for: Renaissance Las Vegas Hotel ...
# Downloading images for: Nevada Day ...
# Downloading images for: Grape Street Cafe &amp; Wine Bar ...
# Downloading images for: The Brass Lounge ...
# Downloading images for: Las Vegas Motor Speedway - The Bullring ...
# Downloading images for: JW Marriott Las Vegas Resort & Spa ...
# Downloading images for: World Stroke Day ...
# Downloading images for: Diwali/Deepavali ...
# Downloading images for: Rockhouse Bar ...
# Downloading images for: Club Madrid ...
# Downloading images for: Legends Sports Bar & Grill ...
# Downloading images for: Grand Event Center at the Golden Nugget ...
# Downloading images for: Place on 7th ...
# Downloading images for: Temple Sinai Las Vegas ...
# Downloading images for: Silver Nugget Casino & Event Center ...
# Downloading images for: Beauty Bar Las Vegas ...
# Downloading images for: The Meet ...
# Downloading images for: Halloween ...
# Downloading images for: World Cities Day ...
# Downloading images for: All Saints' Day ...
# Downloading images for: World Vegan Day ...
# Downloading images for: Sands Expo and Convention Center ...
# Downloading images for: SEMA Show ...
# Downloading images for: International Day to End Impunity for Crimes against Journalists ...
# Downloading images for: All Souls' Day ...
# Downloading images for: Hard Rock Hotel & Casino - Vanity Nightclub ...
# Downloading images for: Monte Carlo Hotel And Casino ...
# Downloading images for: Las Vegas Little Theatre ...
# Downloading images for: Thomas & Mack Center ...
# Downloading images for: HardHat Lounge "Las Vegas" ...
# Downloading images for: Back Stop Sports Pub ...
# Downloading images for: HAZE Nightclub ...
# Downloading images for: Santa Fe Station Hotel & Casino ...
# Downloading images for: DigiWorld Entertainment ...
# Downloading images for: International Day for Preventing the Exploitation of the Environment in War and Armed Conflict ...
# Downloading images for: The Space L.V. ...
# Downloading images for: Daylight Savings ends ...
# Downloading images for: JEWEL Nightclub ...
# Downloading images for: Kellogg-Zaher Park ...
# Downloading images for: The Orleans Hotel & Casino - Orleans Arena ...
# Downloading images for: Valley Bible Fellowship ...
# Downloading images for: Embassy Suites by Hilton Convention Center Las Vegas ...
# Downloading images for: Embassy Suites by Hilton Las Vegas ...
# Downloading images for: Election for US Senate ...
# Downloading images for: Election for US House of Representatives ...
# Downloading images for: Election Day ...
# Downloading images for: Election for President United States of America ...
# Downloading images for: Annual IHC FORUM West ...
# Downloading images for: World Science Day for Peace and Development ...
# Downloading images for: Marine Corps Birthday ...
# Downloading images for: Veterans Day ...
# Downloading images for: The Sci FI Center ...
# Downloading images for: Aliante Golf Club ...
# Downloading images for: World Pneumonia Day ...
# Downloading images for: Cox Pavilion ...
# Downloading images for: Clarion Hotel & Casino ...
# Downloading images for: Chateau Nighclub ...
# Downloading images for: Elks Lodge ...
# Downloading images for: bounty hunter 415 East Windmill Lane  Las Vegas ...
# Downloading images for: Artisan Hotel Boutique ...
# Downloading images for: World Diabetes Day ...
# Downloading images for: Hampton Inn Tropicana ...
# Downloading images for: International Day for Tolerance ...
# Downloading images for: World Philosophy Day ...
# Downloading images for: World Prematurity Day ...
# Downloading images for: Angel Park Golf Club ...
# Downloading images for: E-String ...
# Downloading images for: International Men's Day ...
# Downloading images for: World Toilet Day ...
# Downloading images for: Tivoli Village ...
# Downloading images for: Pearl Concert Theater ...
# Downloading images for: Alexis Park All Suite Resort ...
# Downloading images for: Advanced Technologies Academy ...
# Downloading images for: Town Square Park ...
# Downloading images for: Barnes & Noble ...
# Downloading images for: Universal Children's Day ...
# Downloading images for: Africa Industrialization Day ...
# Downloading images for: World Day of Remembrance for Road Traffic Victims ...
# Downloading images for: South Point ...
# Downloading images for: Official Music District ...
# Downloading images for: Rendezvous Restaurant & Wine Bar ...
# Downloading images for: Fremont Country Club ...
# Downloading images for: Boulder Dam Brewing Co. ...
# Downloading images for: Chi Showroom - Planet Hollywood ...
# Downloading images for: World Television Day ...
# Downloading images for: Thanksgiving Day ...
# Downloading images for: Rock of Ages Theater ...
# Downloading images for: Black Friday ...
# Downloading images for: International Day for the Elimination of Violence against Women ...
# Downloading images for: Day After Thanksgiving ...
# Downloading images for: First Sunday of Advent ...
# Downloading images for: Cyber Monday ...
# Downloading images for: International Day of Solidarity with the Palestinian People ...
# Downloading images for: Hooters Hotel - Night Owl Showroom ...
# Downloading images for: The Westin Las Vegas Hotel  Casino & Spa ...
# Downloading images for: World AIDS Day ...
# Downloading images for: Yardbird Southern Table & Bar ...
# Downloading images for: Titanic: The Artifact Exhibition ...
# Downloading images for: International Day for the Abolition of Slavery ...
# Downloading images for: International Day of Persons with Disabilities ...
# Downloading images for: Fuso Nightclub at Larry Flynt's Hustler Club ...
# Downloading images for: Sunrise Library ...
# Downloading images for: Artemus W. Ham Concert Hall ...
# Downloading images for: World Soil Day ...
# Downloading images for: International Volunteer Day for Economic and Social Development ...
# Downloading images for: Bodies…The Exhibition ...
# Downloading images for: St Nicholas Day ...
# Downloading images for: SILVERTON CASINO HOTEL ...
# Downloading images for: The Golden Tiki ...
# Downloading images for: Pearl Harbor Remembrance Day ...
# Downloading images for: International Civil Aviation Day ...
# Downloading images for: Feast of the Immaculate Conception ...
# Downloading images for: Commonwealth ...
# Downloading images for: International Anti-Corruption Day ...
# Downloading images for: World Genocide Commemoration Day ...
# Downloading images for: Human Rights Day ...
# Downloading images for: Red Rock Fertility Center ...
# Downloading images for: V2 Theater at Planet Hollywood Resort and Casino ...
# Downloading images for: International Mountain Day ...
# Downloading images for: Fantasy ...
# Downloading images for: Caesars Palace Fountains ...
# Downloading images for: Vdara Hotel & Spa ...
# Downloading images for: Feast of Our Lady of Guadalupe ...
# Downloading images for: The Prophet's Birthday ...
# Downloading images for: Laugh Factory Comedy Club ...
# Downloading images for: National Guard Birthday ...
# Downloading images for: Brad Garrett Comedy Club at MGM Grand Hotel and Casino ...
# Downloading images for: Diablo's at Monte Carlo ...
# Downloading images for: Bill of Rights Day ...
# Downloading images for: Firefly ...
# Downloading images for: Pan American Aviation Day ...
# Downloading images for: Wright Brothers Day ...
# Downloading images for: St. Elizabeth Ann Seton Catholic Church ...
# Downloading images for: Leatherneck Club ...
# Downloading images for: Wildhorse Golf Club ...
# Downloading images for: Arabic Language Day ...
# Downloading images for: International Migrants Day ...
# Downloading images for: The Chxrch ...
# Downloading images for: Starbright Theater ...
# Downloading images for: Whitney Library ...
# Downloading images for: Sapphire Las Vegas Gentlemen's Club ...
# Downloading images for: International Human Solidarity Day ...
# Downloading images for: December Solstice ...
# Downloading images for: The Griffin ...
# Downloading images for: Christmas Eve ...
# Downloading images for: Chanukah/Hanukkah (first day) ...
# Downloading images for: Christmas Day ...
# Downloading images for: Mon Ami Gabi ...
# Downloading images for: Kwanzaa (first day) ...
# Downloading images for: New Year's Eve ...
# Downloading images for: The Blue Man Theatre ...
# Downloading images for: 1 Oak Las Vegas at the Mirage Hotel and Casino ...
# Downloading images for: Second City Tours - Clark & Superior ...
# Downloading images for: Last Day of Chanukah ...
# Downloading images for: New Year's Day ...
# Downloading images for: Ron DeCars Event Center ...
# Downloading images for: Baobab Stage Theatre ...
# Downloading images for: The Bank ...
# Downloading images for: Palms Casino Resort - Moon Nightclub ...
# Downloading images for: Cosmopolitan of Las Vegas - The Chelsea ...
# Downloading images for: Bocho Sushi ...
# Downloading images for: Senor Frog's ...
# Downloading images for: MGM Grand - Marquee Ballroom ...
# Downloading images for: World Braille Day ...
# Downloading images for: Westgate LV Resort and Casino-Theater ...
# Downloading images for: Epiphany ...
# Downloading images for: International Programmers' Day ...
# Downloading images for: Orthodox Christmas Day ...
# Downloading images for: Winchester Cultural Center ...
# Downloading images for: Las Vegas Library ...
# Downloading images for: Stratosphere Theatre ...
# Downloading images for: Paris Las Vegas Event Center ...
# Downloading images for: The Venetian - The Gallery ...
# Downloading images for: James I Gibson Library ...
# Downloading images for: Stephen Foster Memorial Day ...
# Downloading images for: Friday the 13th ...
# Downloading images for: University of Nevada  Las Vegas (UNLV) ...
# Downloading images for: Orthodox New Year ...
# Downloading images for: Mt Charleston Hotel ...
# Downloading images for: World Religion Day ...
# Downloading images for: Las Vegas Distillery ...
# Downloading images for: Martin Luther King Jr. Day ...
# Downloading images for: Robert E. Lee's Birthday ...
# Downloading images for: Red Rock Canyon National Conservation Area ...
# Downloading images for: Caesars Palace - The Colosseum ...
# Downloading images for: Surfaces (within TISE) ...
# Downloading images for: Nellis Air Force Base ...
# Downloading images for: University of Nevada Cooperative Extension ...
# Downloading images for: University of Nevada  Las Vegas: Alta Ham Fine Arts  Studio One ...
# Downloading images for: Clique Bar & Lounge ...
# Downloading images for: Surrender ...
# Downloading images for: Turmeric Flavors of India ...
# Downloading images for: Paris Hotel & Casino ...
# Downloading images for: Southern Hills Baptist Church ...
# Downloading images for: International Customs Day ...
# Downloading images for: International Day of Commemoration in Memory of the Victims of the Holocaust ...
# Downloading images for: Humana - Summerlin ...
# Downloading images for: Humana - Henderson ...
# Downloading images for: Chinese New Year ...
# Downloading images for: Gold Mine Tavern ...
# Downloading images for: Huntridge Tavern ...
# Downloading images for: Kansas Day ...
# Downloading images for: World Leprosy Day ...
# Downloading images for: Lucille's Smokehouse Bar-B-Que ...
# Downloading images for: The Martini ...
# Downloading images for: After ...
# Downloading images for: National Demolition Association Convention ...
# Downloading images for: National Freedom Day ...
# Downloading images for: 3930 Cambridge St ...
# Downloading images for: Groundhog Day ...
# Downloading images for: World Wetlands Day ...
# Downloading images for: National Wear Red Day ...
# Downloading images for: Hilton Garden Inn Las Vegas Strip South ...
# Downloading images for: World Cancer Day ...
# Downloading images for: Rocks Lounge ...
# Downloading images for: Tao ...
# Downloading images for: The Windmill Performing Arts Center ...
# Downloading images for: International Day of Zero Tolerance for Female Genital Mutilation ...
# Downloading images for: Encore Hotel & Casino ...
# Downloading images for: Four Points by Sheraton Las Vegas East Flamingo ...
# Downloading images for: World Day of the Sick ...
# Downloading images for: Tu Bishvat/Tu B'Shevat ...
# Downloading images for: International Day of Women and Girls in Science ...
# Downloading images for: Cornerstone Christian Fellowship of Las Vegas ...
# Downloading images for: Mardi Gras Bar ...
# Downloading images for: Jack's Place ...
# Downloading images for: Artifice ...
# Downloading images for: Chinatown Plaza ...
# Downloading images for: World Radio Day ...
# Downloading images for: Valentine's Day ...
# Downloading images for: Cabo Wabo Cantina ...
# Downloading images for: NECHE ...
# Downloading images for: Valley Bible Fellowship Of Las Vegas Church ...
# Downloading images for: The Double Down ...
# Downloading images for: World Day of Social Justice ...
# Downloading images for: Presidents' Day ...
# Downloading images for: Velveteen Rabbit ...
# Downloading images for: International Mother Language Day ...
# Downloading images for: WSA@MAGIC ...
# Downloading images for: Canyon Club ...
# Downloading images for: Maha Shivaratri ...
# Downloading images for: Ravealation ...
# Downloading images for: Las Vegas City Hall ...
# Downloading images for: Green Valley Ranch ...
# Downloading images for: Taste and Sounds of Soul festival ...
# Downloading images for: Count's Vamp'd ...
# Downloading images for: Shrove Tuesday/Mardi Gras ...
# Downloading images for: Self-Injury Awareness Day ...
# Downloading images for: St. David's Day ...
# Downloading images for: Ash Wednesday ...
# Downloading images for: Zero Discrimination Day ...
# Downloading images for: Four Seasons Hotel Las Vegas ...
# Downloading images for: IRE ...
# Downloading images for: Read Across America Day ...
# Downloading images for: Medical Liability and Health Care Law ...
# Downloading images for: World Wildlife Day ...
# Downloading images for: Employee Appreciation Day ...
# Downloading images for: The Meadows School ...
# Downloading images for: TOYFEST WEST ...
# Downloading images for: Moapa River Indian Reservation ...
# Downloading images for: IFPE ...
# Downloading images for: International Women's Day ...
# Downloading images for: World Kidney Day ...
# Downloading images for: Fashion Show Mall ...
# Downloading images for: Majestik Theater ...
# Downloading images for: El Cortez Hotel & Casino ...
# Downloading images for: Holi ...
# Downloading images for: Purim ...
# Downloading images for: Congo Room  The ...
# Downloading images for: Daylight Savings begins ...
# Downloading images for: Las Vegas Motor Speedway ...
# Downloading images for: Oddfellows ...
# Downloading images for: The Palazzo ...
# Downloading images for: EXHIBITORLIVE! (formerly EXHIBITOR Show) ...
# Downloading images for: Roy's - Las Vegas ...
# Downloading images for: Boomers Bar ...
# Downloading images for: TAO Beach ...
# Downloading images for: St. Patrick's Day ...
# Downloading images for: University of Nevada  Las Vegas ...
# Downloading images for: Tommy Rocker's Mojave Beach Bar & Grill ...
# Downloading images for: God's House international ...
# Downloading images for: Club Fortune Casino ...
# Downloading images for: Greenspun Hall Auditorium ...
# Downloading images for: Eclipse ...
# Downloading images for: DROPBAR ...
# Downloading images for: Independence Center ...
# Downloading images for: International Day of Happiness ...
# Downloading images for: March Equinox ...
# Downloading images for: World Poetry Day ...
# Downloading images for: International Day for the Elimination of Racial Discrimination ...
# Downloading images for: World Down Syndrome Day ...
# Downloading images for: International Day of Forests ...
# Downloading images for: International Day of Nowruz ...
# Downloading images for: World Water Day ...
# Downloading images for: World Meteorological Day ...
# Downloading images for: Las Vegas ...
# Downloading images for: World Tuberculosis Day ...
# Downloading images for: International Day for the Right to the Truth concerning Gross Human Rights Violations and for the Dignity of Victims ...
# Downloading images for: CLUB HIS HOP ...
# Downloading images for: Earth Hour ...
# Downloading images for: International Day of Solidarity with Detained and Missing Staff Members ...
# Downloading images for: International Day of Remembrance of Slavery Victims and the Transatlantic Slave Trade ...
# Downloading images for: Terrace Afterhours ...
# Downloading images for: Eastside Cannery ...
# Downloading images for: Fundamentals of Purchasing: The Building Blocks of World-Class Professionalism ...
# Downloading images for: GlobalShop ...
# Downloading images for: Global Shop ...
# Downloading images for: National Vietnam War Veterans Day ...
# Downloading images for: DSE ...
# Downloading images for: The Westin Lake Las Vegas Resort & Spa ...
# Downloading images for: Bar at Times Square ...
# Downloading images for: César Chávez Day ...
# Downloading images for: Club Domina at the Hard Rock Hotel & Casino ...
# Downloading images for: Canyon Club At Four Queens ...
# Downloading images for: The Gossy Room at Caesars Palace ...
# Downloading images for: April Fool's Day ...
# Downloading images for: LA Comedy Club ...
# Downloading images for: The Parlor Cocktail Lounge ...
# Downloading images for: World Autism Awareness Day ...
# Downloading images for: United Nations' Mine Awareness Day ...
# Downloading images for: Earl E. Wilson Baseball Stadium ...
# Downloading images for: Eliphino Dive and Dine ...
# Downloading images for: SLS Las Vegas  a Tribute Portfolio Resort ...
# Downloading images for: International Day of Sport for Development and Peace ...
# Downloading images for: National Tartan Day ...
# Downloading images for: Day of Remembrance of the Victims of the Rwanda Genocide ...
# Downloading images for: United Nations' World Health Day ...
# Downloading images for: 3674 N Rancho Dr ...
# Downloading images for: Palm Sunday ...
# Downloading images for: Pinot's Palette ...
# Downloading images for: Double Down Saloon ...
# Downloading images for: Rainbow Library ...
# Downloading images for: Passover (first day) ...
# Downloading images for: National Library Workers' Day ...
# Downloading images for: International Day of Human Space Flight ...
# Downloading images for: Thomas Jefferson's Birthday ...
# Downloading images for: Maundy Thursday ...
# Downloading images for: Orthodox Good Friday ...
# Downloading images for: The Arts Factory ...
# Downloading images for: Orthodox Holy Saturday ...
# Downloading images for: CEO Hookah Lounge ...
# Downloading images for: Orthodox Easter ...
# Downloading images for: Easter Sunday ...
# Downloading images for: Easter Monday ...
# Downloading images for: Last Day of Passover ...
# Downloading images for: Tax Day ...
# Downloading images for: International Day for Monuments and Sites ...
# Downloading images for: Chinese Language Day ...
# Downloading images for: Surrender Nightclub at Encore ...
# Downloading images for: Global Youth Service Day ...
# Downloading images for: Earth Day ...
# Downloading images for: Mandalay Bay Beach ...
# Downloading images for: World Book and Copyright Day ...
# Downloading images for: English Language Day ...
# Downloading images for: Yom HaShoah ...
# Downloading images for: Isra and Mi'raj ...
# Downloading images for: World Malaria Day ...
# Downloading images for: Keller Williams Southern Nevada ...
# Downloading images for: World Intellectual Property Day ...
# Downloading images for: Administrative Professionals Day ...
# Downloading images for: International Chernobyl Disaster Remembrance Day ...
# Downloading images for: Take our Daughters and Sons to Work Day ...
# Downloading images for: Center for Science & Wonder ...
# Downloading images for: Vegas Uncork’d ...
# Downloading images for: World Day for Safety and Health at Work ...
# Downloading images for: Cashman Field ...
# Downloading images for: TPC Summerlin ...
# Downloading images for: Day of Remembrance for all Victims of Chemical Warfare ...
# Downloading images for: The Innevation Center ...
# Downloading images for: Cheyenne High School ...
# Downloading images for: Rehab Beach Club ...
# Downloading images for: Aston MonteLago Village Resort ...
# Downloading images for: International Jazz Day ...
# Downloading images for: Law Day ...
# Downloading images for: Loyalty Day ...
# Downloading images for: World Tuna Day ...
# Downloading images for: Yom Ha'atzmaut ...
# Downloading images for: World Press Freedom Day ...
# Downloading images for: Annual Conference And Exposition ...
# Downloading images for: HDexpo ...
# Downloading images for: Art Of Music Gallery ...
# Downloading images for: National Day of Prayer ...
# Downloading images for: Cinco de Mayo ...
# Downloading images for: National Explosive Ordnance Disposal (EOD) Day ...
# Downloading images for: National Nurses Day ...
# Downloading images for: Las Vegas Baby Co. ...
# Downloading images for: Clark County Government Center ...
# Downloading images for: Dell EMC World ...
# Downloading images for: Conference Center of Las Vegas ...
# Downloading images for: Victory in Europe Day ...
# Downloading images for: Time of Remembrance and Reconciliation for Those Who Lost Their Lives during the Second World War ...
# Downloading images for: World Ovarian Cancer Day ...
# Downloading images for: NHS ...
# Downloading images for: Day of Vesak ...
# Downloading images for: Military Spouse Appreciation Day ...
# Downloading images for: International Nurses Day ...
# Downloading images for: Las Vegas Village ...
# Downloading images for: Juicy Beets ...
# Downloading images for: World Migratory Bird Day ...
# Downloading images for: Lag BaOmer ...
# Downloading images for: Mother's Day ...
# Downloading images for: International Day of Families ...
# Downloading images for: Peace Officers Memorial Day ...
# Downloading images for: World Information Society Day ...
# Downloading images for: Enchanted Forest Reiki Center ...
# Downloading images for: National Defense Transportation Day ...
# Downloading images for: Emergency Ultrasound Course ...
# Downloading images for: Armed Forces Day ...
# Downloading images for: PBR ROCK BAR & GRILL ...
# Downloading images for: Rehab at Hard Rock Hotel and Casino Las Vegas ...
# Downloading images for: The LINQ ...
# Downloading images for: Lake Las Vegas ...
# Downloading images for: World Day for Cultural Diversity for Dialogue and Development ...
# Downloading images for: The Cosmopolitan of Las Vegas - Boulevard Pool ...
# Downloading images for: National Maritime Day ...
# Downloading images for: International Day for Biological Diversity ...
# Downloading images for: Onyx Theatre ...
# Downloading images for: International Day to End Obstetric Fistula ...
# Downloading images for: Emergency Medical Services for Children Day ...
# Downloading images for: African Liberation Day ...
# Downloading images for: National Missing Children's Day ...
# Downloading images for: Ascension Day ...
# Downloading images for: Ramadan Starts ...
# Downloading images for: Zemskov Dance Academy ...
# Downloading images for: Thunderbird Lounge and Bar ...
# Downloading images for: Cowabunga Bay Las Vegas ...
# Downloading images for: Las Vegas Harley Davidson ...
# Downloading images for: Ballroom Addiction ...
# Downloading images for: International Day of United Nations Peacekeepers ...
# Downloading images for: Memorial Day ...
# Downloading images for: Marquee Las Vegas ...
# Downloading images for: Saxe Theater at Planet Hollywood Inside the Miracle Mile Mall ...
# Downloading images for: Linq - Mat Franco Theater ...
# Downloading images for: Shavuot ...
# Downloading images for: World No Tobacco Day ...
# Downloading images for: Global Day of Parents ...
# Downloading images for: Stratosphere Hotel and Casino - The Dragon Room ...
# Downloading images for: Caesars Palace - Spiegeltent ...
# Downloading images for: Las Vegas Events - The Tommy Wind Theater & Events Center ...
# Downloading images for: COUTURE ...
# Downloading images for: Craig Ranch Park ...
# Downloading images for: Total Wine ...
# Downloading images for: Hotel Shuttle Pickup ...
# Downloading images for: The Corner Gallery ...
# Downloading images for: Hotel Suite TBA ...
# Downloading images for: International Day of Innocent Children Victims of Aggression ...
# Downloading images for: Pentecost ...
# Downloading images for: Loco Cantina ...
# Downloading images for: AGTA GemFair ...
# Downloading images for: World Environment Day ...
# Downloading images for: Whit Monday ...
# Downloading images for: HP Discover Episode ...
# Downloading images for: Clean Show ...
# Downloading images for: D-Day ...
# Downloading images for: World Oceans Day ...
# Downloading images for: Curago Vita Wellness Institute ...
# Downloading images for: Fiesta Rancho Hotel & Casino ...
# Downloading images for: Regal Cinemas Village Square 18 ...
# Downloading images for: Code Central - Henderson ...
# Downloading images for: Trinity Sunday ...
# Downloading images for: World Day Against Child Labour ...
# Downloading images for: MGM Grand--Las Vegas ...
# Downloading images for: International Albinism Awareness Day ...
# Downloading images for: World Blood Donor Day ...
# Downloading images for: Army Birthday ...
# Downloading images for: Flag Day ...
# Downloading images for: Corpus Christi ...
# Downloading images for: World Elder Abuse Awareness Day ...
# Downloading images for: Wet Republic ...
# Downloading images for: International Day of Family Remittances ...
# Downloading images for: World Day to Combat Desertification and Drought ...
# Downloading images for: Elixir - A Local Lounge ...
# Downloading images for: Centennial Hills YMCA ...
# Downloading images for: Father's Day ...
# Downloading images for: International Day for the Elimination of Sexual Violence in Conflict ...
# Downloading images for: American Eagle Day ...
# Downloading images for: World Refugee Day ...
# Downloading images for: International Day of Yoga ...
# Downloading images for: Lailat al-Qadr ...
# Downloading images for: June Solstice ...
# Downloading images for: The Cabaret at Planet Hollywood Las Vegas ...
# Downloading images for: Public Service Day ...
# Downloading images for: International Widows' Day ...
# Downloading images for: Tenaya Creek Brewery ...
# Downloading images for: Palms Casino Resort - The Lounge ...
# Downloading images for: Day of the Seafarer ...
# Downloading images for: International Day Against Drug Abuse and Illicit Trafficking ...
# Downloading images for: International Day in Support of Victims of Torture ...
# Downloading images for: Eid al-Fitr ...
# Downloading images for: Congregation Ner Tamid ...
# Downloading images for: International Asteroid Day ...
# Downloading images for: International Day of Cooperatives ...
# Downloading images for: Independence Day ...
# Downloading images for: Ghostbar ...
# Downloading images for: House of Blues Las Vegas - Foundation Room ...
# Downloading images for: Naturally Organic Healing Center ...
# Downloading images for: Club His Hop Las Vegas ...
# Downloading images for: Courtyard Berlin City Center ...
# Downloading images for: World Population Day ...
# Downloading images for: Bastille Day ...
# Downloading images for: World Youth Skills Day ...
# Downloading images for: Crosswinds Community Church ...
# Downloading images for: Pearson Community Center ...
# Downloading images for: Nelson Mandela Day ...
# Downloading images for: Henderson Executive Airport ...
# Downloading images for: Parents' Day ...
# Downloading images for: Broadacres Marketplace ...
# Downloading images for: Keller Williams Realty Las Vegas ...
# Downloading images for: National Korean War Veterans Armistice Day ...
# Downloading images for: DEF CON ...
# Downloading images for: World Hepatitis Day ...
# Downloading images for: Hard Rock Hotel & Casino - Poolside ...
# Downloading images for: International Day of Friendship ...
# Downloading images for: World Day against Trafficking in Persons ...
# Downloading images for: The Las Vegas Country Club ...
# Downloading images for: Sapphire Showroom ...
# Downloading images for: Hard Rock Cafe ...
# Downloading images for: Spanish Trail Country Club ...
# Downloading images for: Adelson Educational Campus ...
# Downloading images for: Tisha B'Av ...
# Downloading images for: XS Las Vegas ...
# Downloading images for: Coast Guard Birthday ...
# Downloading images for: Center For Spiritual Living Greater Las Vegas ...
# Downloading images for: Redflint ...
# Downloading images for: House of Blues - Restaurant & Bar ...
# Downloading images for: Raksha Bandhan ...
# Downloading images for: Purple Heart Day ...
# Downloading images for: Regenexx Las Vegas Clinic ...
# Downloading images for: International Day of the World's Indigenous People ...
# Downloading images for: International Youth Day ...
# Downloading images for: Cork and Thorn ...
# Downloading images for: Sahara Lounge ...
# Downloading images for: Janmashtami ...
# Downloading images for: MAGIC ...
# Downloading images for: Assumption of Mary ...
# Downloading images for: PGA Fashion & Demo Experience (formerly PGA Fall Expo) ...
# Downloading images for: National Aviation Day ...
# Downloading images for: World Humanitarian Day ...
# Downloading images for: Senior Citizens Day ...
# Downloading images for: International Day for the Remembrance of the Slave Trade and its Abolition ...
# Downloading images for: Ganesh Chaturthi ...
# Downloading images for: Centennial Hills Hospital Medical Center - Jobs and Careers ...
# Downloading images for: The Platinum Hotel & Spa ...
# Downloading images for: Silhouette Bridal ...
# Downloading images for: Women's Equality Day ...
# Downloading images for: The Epicurean Club in Las Vegas - Artisan Hotel ...
# Downloading images for: Hilton Grand Vacations on the Boulevard ...
# Downloading images for: The Venue Las Vegas ...
# Downloading images for: Bellagio Hotel & Casino ...
# Downloading images for: Broadway Hall ...
# Downloading images for: International Day against Nuclear Tests ...
# Downloading images for: International Day of the Victims of Enforced Disappearances ...
# Downloading images for: International Overdose Awareness Day ...
# Downloading images for: Eid al-Adha ...
# Downloading images for: Palms Casino Resort - Palms Pool & Dayclub ...
# Downloading images for: Labor Day ...
# Downloading images for: World Sexual Health Day ...
# Downloading images for: International Day of Charity ...
# Downloading images for: Mandarin Oriental  Las Vegas ...
# Downloading images for: International Literacy Day ...
# Downloading images for: Cashman Center - Theater ...
# Downloading images for: Carl Garner Federal Lands Cleanup Day ...
# Downloading images for: Central Church ...
# Downloading images for: Desert Breeze Park ...
# Downloading images for: World Suicide Prevention Day ...
# Downloading images for: National Grandparents Day ...
# Downloading images for: Patriot Day ...
# Downloading images for: La Quinta Inn ...
# Downloading images for: International Day for South-South Cooperation ...
# Downloading images for: Vision Expo West ...
# Downloading images for: National POW/MIA Recognition Day ...
# Downloading images for: International Day of Democracy ...
# Downloading images for: International Day for the Preservation of the Ozone Layer ...
# Downloading images for: National CleanUp Day ...
# Downloading images for: Encounter Church Las Vegas ...
# Downloading images for: Rolling in the Dough ...
# Downloading images for: New York-New York Hotel & Casino - Nine Fine Irishmen ...
# Downloading images for: Constitution Day and Citizenship Day ...
# Downloading images for: Mirage Events Center at Mirage Hotel and Casino ...
# Downloading images for: Air Force Birthday ...
# Downloading images for: Navratri ...
# Downloading images for: UNLV - International Gaming Institute ...
# Downloading images for: International Day of Peace ...
# Downloading images for: September Equinox ...
# Downloading images for: Muharram ...
# Downloading images for: iHeartRadio Music Festival ...
# Downloading images for: International Celebrate Bisexuality Day ...
# Downloading images for: Lake Mead Marina ...
# Downloading images for: Gold Star Mother's Day ...
# Downloading images for: International Day for the Total Elimination of Nuclear Weapons ...
# Downloading images for: World Tourism Day ...
# Downloading images for: World Maritime Day ...
# Downloading images for: World Rabies Day ...
# Downloading images for: World Heart Day ...
# Downloading images for: Las Vegas Review Journal ...
# Downloading images for: The Lot at Western Hotel ...
# Downloading images for: World Vegetarian Day ...
# Downloading images for: International Day of Older Persons ...
# Downloading images for: International Day of Non-Violence ...
# Downloading images for: Child Health Day ...
# Downloading images for: World Habitat Day ...
# Downloading images for: Feast of St Francis of Assisi ...
# Downloading images for: World Teachers' Day ...
# Downloading images for: The Crossing Church - Las Vegas ...
# Downloading images for: National Association of Criminal Defense Lawyers - DUI Meeting ...
# Downloading images for: World Cerebral Palsy Day ...
# Downloading images for: Art Square Theatre ...
# Downloading images for: Panevino Lounge ...
# Downloading images for: Gravady Extreme Air Sports ...
# Downloading images for: Fremont Street Experience ...
# Downloading images for: Lowden Theater at LVA ...
# Downloading images for: Historic Fifth Street School ...
# Downloading images for: Juicy Beats ...
# Downloading images for: The Mob Museum ...
# Downloading images for: Gordon Biersch Brewery Restaurant ...
# Downloading images for: Credit Union Call Center Conference ...
# Downloading images for: Sitecore Symposium Las Vegas ...
# Downloading images for: Blue Planet Lighting ...
# Downloading images for: Ellis Island Casino & Brewery ...
# Downloading images for: Planet Hollywood Resort and Casino - Criss Angel Theater ...
# Downloading images for: Boomers Lounge ...
# Downloading images for: F.E.I. Construction "Fair Grounds" ...
# Downloading images for: SUN CITY ALIANTE VISTA CABARET ...
# Downloading images for: Kama Rooftop Ultra Lounge ...
# Downloading images for: Dignity Health - St. Rose Dominican  San Martin Campus ...
# Downloading images for: UNLV ...
# Downloading images for: Bonefish Grill ...
# Downloading images for: Desert Wind Coffee Roasters ...
# Downloading images for: United Way of Southern Nevada ...
# Downloading images for: Club 2100 ...
# Downloading images for: Summerlin Community Baptist Church ...
# Downloading images for: Waves Las Vegas ...
# Downloading images for: Embassy Nightclub ...
# Downloading images for: MGM Grand Conference Center ...
# Downloading images for: Jubilee Theater at Bally's Las Vegas ...
# Downloading images for: Marjorie Barrick Museum ...
# Downloading images for: Tropicana Hotel - Tropicana Theater ...
# Downloading images for: Fleming's Prime Steakhouse & Wine Bar ...
# Downloading images for: Eclipse Theaters ...
# Downloading images for: RedFlint Experience Center ...
# Downloading images for: Siena Community Association ...
# Downloading images for: Hilton Theater ...
# Downloading images for: Royal Resort ...
# Downloading images for: Las Vegas Marriott ...
# Downloading images for: Craig Ranch Amphitheater ...
# Downloading images for: Shadow Hills Church ...
# Downloading images for: La Jolla ...
# Downloading images for: Hard Rock Hotel & Casino - Magic Mike Live ...
# Downloading images for: Dragonridge Country Club ...
# Downloading images for: William S. Boyd School of Law - Tam Hall ...
# Downloading images for: Blue Martini Lounge ...
# Downloading images for: Priscilla Fowler Fine Art ...
# Downloading images for: UNLV SRWC Rec Center ...
# Downloading images for: Reggae Beach Club ...
# Downloading images for: Luna Hookah Lounge ...
# Downloading images for: Capstone Brokerage  Inc. ...
# Downloading images for: Addisons Lounge at the Rampart CAsino ...
# Downloading images for: Las Vegas Academy of the Arts Performing Arts Center ...
# Downloading images for: Inspire Theater ...
# Downloading images for: North Las Vegas City Hall ...
# Downloading images for: Jin's Club ...
# Downloading images for: Fresha Wata HQ ...
# Downloading images for: Fogo De Chao Brazilian Steakhouse ...
# Downloading images for: Spring Valley Hospital Medical Center ...
# Downloading images for: Tempo Afterhours ...
# Downloading images for: Durango High School ...
# Downloading images for: Enclave ...
# Downloading images for: Bears Best Country Club ...
# Downloading images for: Italian American Club Restaurant ...
# Downloading images for: The Back Room at Bally's Las Vegas ...
# Downloading images for: Stateside Lounge ...
# Downloading images for: Hustler Club Las Vegas ...
# Downloading images for: kallzu Vegas Live Event ...
# Downloading images for: PT's Ranch ...
# Downloading images for: Midnight Comedy Show with Cookie Hull ...
# Downloading images for: Tempo ...
# Downloading images for: Cleveland Clinic Multispecialty Pathology Symposium ...
# Downloading images for: Tahiti Village Resort ...
# Downloading images for: Millennium Fandom Bar ...
# Downloading images for: Ninja Karaoke ...
# Downloading images for: Park Theater ...
# Downloading images for: Funderdome! Improv Comedy Battle ...
# Downloading images for: Rampart Casino ...
# Downloading images for: Justin Tranz Comedy Hypnosis ...
# Downloading images for: University Of Las Vegas ...
# Downloading images for: Sport Center of Las Vegas ...
# Downloading images for: Institution ...
# Downloading images for: CAWRAM at the Thunderbird ...
# Downloading images for: Total Care Family Practice ...
# Downloading images for: ABOUT LAST NIGHT "Hakkasan Nightclub presents Lil Jon" ...
# Downloading images for: Rancho High School ...
# Downloading images for: Las Vegas Metropolitan Police Department Headquarters ...
# Downloading images for: Opera in the Movies ...
# Downloading images for: WEICHERT  REALTORS® - Millennium ...
# Downloading images for: Bally's Las Vegas Hotel & Casino (Skyview 5) ...
# Downloading images for: Africa Love Gift & Decor Store (Town Square) ...
# Downloading images for: Evel Pie ...
# Downloading images for: 6655 Sahara Ave ...
# ...
# Downloading images for: Health South Rehabilitation Hospital ...
# Downloading images for: Tuscany Suites & Casino Florentine Ballroom and Tuscany Event Center – 2nd Floor ...
# Downloading images for: Encore Las Vegas 3131 S Las Vegas Blvd Las Vegas  Nevada  United States Of America ...
# Downloading images for: No Regrets Bar ...
# Downloading images for: Green Valley High School ...
# Downloading images for: Miller Lite Conciertos Originales - Las Vegas  NV ...
# Downloading images for: American Dream U ...
# Downloading images for: Galleria at Sunset ...
# Downloading images for: June Small Business Marketing Series: From Facebook to Funnels ...
# Downloading images for: 3150 Paradise Road ...
# Downloading images for: DIBELS Super Institute and Mentor Summit ...
# Downloading images for: Paris Las Vegas Pool ...
# Downloading images for: Shark Reef Aquarium at Mandalay Bay ...
# Downloading images for: Paris Theater ...
# Downloading images for: Opium Theatre at the Cosmopolitan of Las Vegas ...
# Downloading images for: Strawberri Taylor presents : Sugar Brown Burlesque Bad & Bougie Comedy ...
# Downloading images for: Jubilee Theater at Ballys Las Vegas ...
# Downloading images for: Viva Las Vegas ...
# Downloading images for: Courtyard by Marriott Las Vegas Summerlin ...
# Downloading images for: Cockroach Theatre ...
# Downloading images for: Citrus Grand Pool Deck ...
# Downloading images for: 1 OAK ...
# Downloading images for: Acres Underground / Cannabis Leadership Expo ...
# Downloading images for: Harrah's Cabaret at Harrah's Las Vegas ...
# Downloading images for: PBA Beauty Week ...
# Downloading images for: MGM Resorts International ...
# Downloading images for: Rio Showroom at Rio Las Vegas ...
# Downloading images for: Gold Strike Hotel & Gambling Hall ...
# Downloading images for: The Industrial Event Space ...
# Downloading images for: The Terrrace over Sake Rok ...
# Downloading images for: Ri Ra Irish Pub ...
# Downloading images for: Retail Realm Technology Conference ...
# Downloading images for: East Las Vegas Community/Senior Center ...
# Downloading images for: InStyle Flooring & Designs Showroom ...
# Downloading images for: The Shattered Bar ...
# Downloading images for: Exodus Festival Las Vegas - Labour Day Weekend ...
# Downloading images for: Larry Flynt's Hustler Club - Las Vegas Strip Club ...
# Downloading images for: Jillians Las Vegas ...
# Downloading images for: Carnevino ...
# Downloading images for: The Fetus & Newborn ...
# Downloading images for: Century Orleans 18 Movie Theater ...
# Downloading images for: House of Tape at Harrah's Las Vegas ...
# Downloading images for: Rosh Hashana ...
# Downloading images for: FMLA Compliance Update ...
# Downloading images for: Mirage Convention Center ...
# Downloading images for: Caesars Palace - Palace Ballroom ...
# Downloading images for: Yom Kippur ...
# Downloading images for: Word of Life Christian Center ...
# Downloading images for: Serenity Birth Center ...
# Downloading images for: Las Vegas Festival Grounds ...
# Downloading images for: Babes Rockin' Sports Bar ...
# Downloading images for: Era D2C Convention ...
# Downloading images for: Drai's Rooftop Nightclub ...
# Downloading images for: Opportunity Village ...
# Downloading images for: Adobe ColdFusion Summit ...
# Downloading images for: Pediatric Critical Care Nursing Conference ...
# Downloading images for: NACS Show ...
# Downloading images for: Waldorf Astoria Hotel ...
# Downloading images for: SWE - Service World Expo ...
# Downloading images for: AIMExpo ...
# Downloading images for: Spring Valley High School ...
# Downloading images for: Railroad Pass Hotel & Casino ...
# Downloading images for: National Conference & Trade Show ...
# Downloading images for: Live Design International Show ...
# Downloading images for: International Congress on Nosocomial and Healthcare associated Infections ...
# Downloading images for: Homewood Suites by Hilton® Las Vegas Airport ...
# Downloading images for: The Children's Cabinet ...
# Downloading images for: MPOWER Cybersecurity Summit ...
# Downloading images for: Stones Spot ...
# Downloading images for: Organization Skills for the Overwhelmed ...
# Downloading images for: National Conference on Correctional Health Care ...
# Downloading images for: Las Vegas RoadShow ...
# Downloading images for: Trump International Hotel Las Vegas ...
# Downloading images for: Stoller's Current Issues of Magnetic Resonance Imaging In Orthopaedics and Sports Medicine ...
# Downloading images for: The Las Vegas Franchise Show ...
# Downloading images for: The Hideaway ...
# Downloading images for: Calvary Chapel Las Vegas ...
# Downloading images for: DUB Show Tour ...
# Downloading images for: Caesar's Palace ...
# Downloading images for: Cornerstone Park ...
# Downloading images for: Courtyard by Marriott Las Vegas Henderson/Green Valley ...
# Downloading images for: Tribalnet Conference and Exhibition ...
# Downloading images for: Viva Las Vegas Conference ...
# Downloading images for: Production Technology & Operations Conference ...
# Downloading images for: Reaching Your Members ...
# Downloading images for: AICPA Controllers Workshop ...
# Downloading images for: Advanced Employment Issues Symposium ...
# Downloading images for: Learning Tech Driving Progress and Innovation in Workforce Development ...
# Downloading images for: 172 ...
# Downloading images for: SnowJam Show Las Vegas ...
# Downloading images for: The Truth Spot LV ...
# Downloading images for: Managing Human Resources ...
# Downloading images for: Current Psychiatry Conference ...
# Downloading images for: Psychiatry Update Encore Presentation ...
# Downloading images for: DEV intersection ...
# Downloading images for: Anglebrackets Conference ...
# Downloading images for: Aarc Congress & Exhibition ...
# Downloading images for: Aicpa Real Estate Conference ...
# Downloading images for: Hostile Grape ...
# Downloading images for: Aerial Fitness ...
# Downloading images for: International Conference on Computational Science and Computational Intelligence ...
# Downloading images for: Mickie Finnz Fish House & Bar ...
# Downloading images for: Las Vegas  NV - City National Arena ...
# Downloading images for: Hardrock Live ...
# Downloading images for: Fort Cheyenne Event Center ...
# Downloading images for: Sundance Helicopters ...
# Downloading images for: Brand Innovators Mega Trends ...
# Downloading images for: International CES - Consumer Electronics Show ...
# Downloading images for: BabyTech Summit ...
# Downloading images for: Caesars Palace - Octavius Ballroom ...
# Downloading images for: AFRDS Conference & Expo ...
# Downloading images for: South Point Showroom at South Point Hotel Casino and Spa ...
# Downloading images for: InterNext ...
# Downloading images for: Troesh Studio Theater at The Smith Center ...
# Downloading images for: Global Specialty Lens Symposium ...
# Downloading images for: Hard Rock Hotel and Casino - Hard Rock Cafe ...
# Downloading images for: West Coast Art & Frame Expo & The National Conference ...
# Downloading images for: Zappos Theater ...
# Downloading images for: The Urban Lounge ...
# Downloading images for: Silverado High School ...
# Downloading images for: NAPO Executive Board Meeting ...
# Downloading images for: Police  Fire  EMS  and Municipal Employee Pension & Benefits Seminar ...
# Downloading images for: The Packaging Conference ...
# Downloading images for: Cremation Symposium ...
# Downloading images for: Chron's and Colitis Congress ...
# Downloading images for: Escaped Vegas at Bally's Las Vegas ...
# Downloading images for: The Venetian - The Palazzo Ballroom ...
# Downloading images for: eLearning Conference ...
# Downloading images for: Annual National Psychopharmacology Update Conference ...
# Downloading images for: Snack & Dry Grocery EPPS ...
# Downloading images for: AOG Conference ...
# Downloading images for: Parker Seminars Las Vegas ...
# Downloading images for: NPI Conference ...
# Downloading images for: Rhythms Event Center ...
# Downloading images for: National Provider Enrollment Forum ...
# Downloading images for: Wedding and Portrait Photographers International Trade Show ...
# Downloading images for: Digital Mammography Training ...
# Downloading images for: Hampton Inn & Suites Las Vegas Airport ...
# Downloading images for: Multi-State Salinity Coalition Salinity Summit ...
# Downloading images for: Reynolds Hall - Smith Center for the Performing Arts ...
# Downloading images for: Cardio/Pulmonary Medicine for Primary Care ...
# Downloading images for: Cardiology & Pulmonology for Primary Care ...
# Downloading images for: BOWIE'S LV ...
# Downloading images for: Las vegas ...
# Downloading images for: Multidisciplinary Conference Las Vegas ...
# Downloading images for: ASPS Aesthetica ...
# Downloading images for: Encore Beach Club - Wynn Las Vegas ...
# Downloading images for: Annual Interdisciplinary Breast Center Conference ...
# Downloading images for: Agewell Expo ...
# Downloading images for: Artisan Craft Festival ...
# Downloading images for: Wtui Conference & Exhibition ...
# Downloading images for: Independent Retailer Conference ...
# Downloading images for: Credit Department Management Forum ...
# Downloading images for: International SITE Conference ...
# Downloading images for: Vegas national fabric show ...
# Downloading images for: ITAR Defense Trade Controls ...
# Downloading images for: MGM Grand Hotel & Casino ...
# Downloading images for: ERA Real Estate Conference ...
# Downloading images for: International Business Conference ...
# Downloading images for: CUNA Marketing & Business Development Council Conference Las Vegas ...
# Downloading images for: EAR / OFAC Export Controls ...
# Downloading images for: National Family Medicine Board Review ...
# Downloading images for: Loan Review Department Managers Forum ...
# Downloading images for: La Quinta Inn & Suites Las Vegas Airport South ...
# Downloading images for: Las Vegas Parenting Expo ...
# Downloading images for: Henderson Pet Expo ...
# Downloading images for: HR in Hospitality Expo ...
# Downloading images for: National Reservation Economic Summit ...
# Downloading images for: Nightclub & Bar Convention & Trade Show ...
# Downloading images for: The Travel Goods Show ...
# Downloading images for: Amusement Expo ...
# Downloading images for: Marquee Dayclub Pool ...
# Downloading images for: Atmosphere ...
# Downloading images for: Connections ...
# Downloading images for: PBS Technology Conference ...
# Downloading images for: Saxe Theater - Planet Hollywood Resort & Casino ...
# Downloading images for: Roy Martin Middle School ...
# Downloading images for: Whitney Peak Hotel ...
# Downloading images for: Canyon Ridge Christian Church ...
# Downloading images for: Payroll Law ...
# Downloading images for: UNLVino ...
# Downloading images for: Sunset Park Las vegas ...
# Downloading images for: Exposition and Conference ...
# Downloading images for: Hamburger Mary's - Las Vegas ...
# Downloading images for: Viva Las Vegas Rockabilly Weekender ...
# Downloading images for: HRSG users conference ...
# Downloading images for: MRI Of The Head And Spine National Symposium ...
# Downloading images for: Imaging & Technology Education Expo ...
# Downloading images for: MSPExpo ...
# Downloading images for: SRPE Educational Conference ...
# Downloading images for: NevAEYC State Conference ...
# Downloading images for: Most Powerful Women in Network Marketing ...
# Downloading images for: Annual MRI of the Body and Heart National Symposium ...
# Downloading images for: Lvl Up Expo ...
# Downloading images for: The Nth Ultimate Whisky Experience ...
# Downloading images for: Maryland Pkwy ...
# Downloading images for: International Tourism Security Conference ...
# Downloading images for: SIA Global Executive Summit ...
# Downloading images for: Asembia's Specialty Pharmacy Summit ...
# Downloading images for: Southern Nevada Health District ...
# Downloading images for: IT Audit School ...
# Downloading images for: Global Travel Marketplace West ...
# Downloading images for: Jimmy Kimmels Comedy Club ...
# Downloading images for: Exodus Festival Las Vegas ...
# Downloading images for: Bassrush Massive - Las Vegas ...
# Downloading images for: Kaos Nightclub ...
# Downloading images for: Locals Coins Show ...
# Downloading images for: Indoor Ag-Con ...
# Downloading images for: Jimmy Kimmel's Comedy Club ...
# Downloading images for: Royal Hookah Lounge ...
# Downloading images for: Chateau ...
# Downloading images for: Swiss Watch By JCK ...
# Downloading images for: CFMAS Conference & Exhibition ...
# Downloading images for: Women's Expo ...
# Downloading images for: Pega World ...
# Downloading images for: Coca-Cola Store Las Vegas ...
# Downloading images for: Western Roofing Expo ...
# Downloading images for: Practitioners Symposium and TECH+ Conference ...
# Downloading images for: Zak Bagans' The Haunted Museum ...
# Downloading images for: HR Law ...
# Downloading images for: Cleopatra's Barge at Caesars Palace ...
# Downloading images for: Chippendales Theatre at The Rio Vegas ...
# Downloading images for: Neurology for Primary Care ...
# Downloading images for: International Bowl Expo ...
# Downloading images for: Seamless Club ...
# Downloading images for: Anesthesia Jackpot Meeting ...
# Downloading images for: THE JAM Open Mic Night @ Ninja Karaoke ...
# Downloading images for: James Regional Sports Park - Field 11 ...
# Downloading images for: Electrical Apparatus Service Association Convention ...
# Downloading images for: Celestia Theater At Stratosphere Las Vegas ...
# Downloading images for: Unplugged - Open Mic ...
# Downloading images for: School Climate & Culture Forum ...
# Downloading images for: Innovative School Summit ...
# Downloading images for: Colonnade 14 ...
# Downloading images for: Las Vegas Meetup 89109 ...
# Downloading images for: Freedom Fest ...
# Downloading images for: Tropicana Las Vegas  Cohiba Ballroom ...
# Downloading images for: MEET Las Vegas ...
# Downloading images for: Source Direct at ASD ...
# Downloading images for: International Conference on Internet Computing and Internet of Things ...
# Downloading images for: Beatleshow GA ...
# Downloading images for: Hookah Expo Worldwide ...
# Downloading images for: High Roller ...
# Downloading images for: Kid's Hub - Las Vegas ...
# Downloading images for: Rio Convention Center ...
# Downloading images for: THE TENTS ...
# Downloading images for: Radisson Hotel ...
# Downloading images for: Sahara Theater ...
# Downloading images for: Official Metal District ...
# Downloading images for: HTLive Conference ...
# Downloading images for: Originator Connect ...
# Downloading images for: South Point Hotel  Casino & Spa - Exhibit Hall & Arena ...
# Downloading images for: Iconic ...
# Downloading images for: National Ergonomics Conference and ErgoExpo ...
# Downloading images for: Spring Mountain Ranch State Park ...
# Downloading images for: Comprehensive EKG ...
# Downloading images for: Radwaste Summit ...
# Downloading images for: Self Storage Association Conference & Trade Show ...
# Downloading images for: Foundation Room Rooftop Nightclub Free entry! ...
# Downloading images for: Harvest Festival Original Art & Craft Show-Las Vegas ...
# Downloading images for: Bally's Las Vegas - Event Center ...
# Downloading images for: Thunderland Showroom at Excalibur ...
# Downloading images for: Credit Union Services And Products Conference ...
# Downloading images for: IMEX America ...
# Downloading images for: Wild On Wounds ...
# Downloading images for: International Watch & Jewelry Guild Show ...
# Downloading images for: THE EXPERIENCE Convention & Trade Show ...
# Downloading images for: International Foot and Ankle Foundation Annual Las Vegas Seminar ...
# Downloading images for: Aria Resort & Casino ...
# Downloading images for: Digital Mortgage ...
# Downloading images for: Las Vegas Job Fair ...
# Downloading images for: OATI Energy Conference Las Vegas ...
# Downloading images for: The Phoenix Bar & Lounge ...
# Downloading images for: AACS Convention & Expo ...
# Downloading images for: The Boulevard Mall ...
# Downloading images for: The Sandbar at Red Rock Casino Resort ...
# Downloading images for: Multifamily Executive Conference ...
# Downloading images for: Rise Festival ...
# Downloading images for: Pubcon Las Vegas ...

# %% [markdown]
# # Places365-CNN for classifying venue images

# %%
# !pip install Pillow
# Out:
# Requirement already satisfied: Pillow in /usr/local/lib/python3.6/dist-packages (4.3.0)
# Requirement already satisfied: olefile in /usr/local/lib/python3.6/dist-packages (from Pillow) (0.46)

# %%
# https://github.com/CSAILVision/places365/blob/master/run_placesCNN_unified.py
# Demo: http://places2.csail.mit.edu/demo.html
# PlacesCNN to predict the scene category, attribute, and 
# class activation map in a single pass
# by Bolei Zhou, sep 2, 2017

import torch
from torch.autograd import Variable as V
import torchvision.models as models
from torchvision import transforms as trn
from torch.nn import functional as F
import os
import numpy as np
# from scipy.misc import imresize as imresize
import cv2
from PIL import Image


def load_labels():
    # prepare all the labels
    # scene category relevant
    file_name_category = 'categories_places365.txt'
    if not os.access(file_name_category, os.W_OK):
        synset_url = 'https://raw.githubusercontent.com/csailvision/places365/master/categories_places365.txt'
        os.system('wget ' + synset_url)
    classes = list()
    with open(file_name_category) as class_file:
        for line in class_file:
            classes.append(line.strip().split(' ')[0][3:])
    classes = tuple(classes)

    # indoor and outdoor relevant
    file_name_IO = 'IO_places365.txt'
    if not os.access(file_name_IO, os.W_OK):
        synset_url = 'https://raw.githubusercontent.com/csailvision/places365/master/IO_places365.txt'
        os.system('wget ' + synset_url)
    with open(file_name_IO) as f:
        lines = f.readlines()
        labels_IO = []
        for line in lines:
            items = line.rstrip().split()
            labels_IO.append(int(items[-1]) -1) # 0 is indoor, 1 is outdoor
    labels_IO = np.array(labels_IO)

    # scene attribute relevant
    file_name_attribute = 'labels_sunattribute.txt'
    if not os.access(file_name_attribute, os.W_OK):
        synset_url = 'https://raw.githubusercontent.com/csailvision/places365/master/labels_sunattribute.txt'
        os.system('wget ' + synset_url)
    with open(file_name_attribute) as f:
        lines = f.readlines()
        labels_attribute = [item.rstrip() for item in lines]
    file_name_W = 'W_sceneattribute_wideresnet18.npy'
    if not os.access(file_name_W, os.W_OK):
        synset_url = 'http://places2.csail.mit.edu/models_places365/W_sceneattribute_wideresnet18.npy'
        os.system('wget ' + synset_url)
    W_attribute = np.load(file_name_W)

    return classes, labels_IO, labels_attribute, W_attribute

def hook_feature(module, input, output):
    features_blobs.append(np.squeeze(output.data.cpu().numpy()))

# def returnCAM(feature_conv, weight_softmax, class_idx):
#     # generate the class activation maps upsample to 256x256
#     size_upsample = (256, 256)
#     nc, h, w = feature_conv.shape
#     output_cam = []
#     for idx in class_idx:
#         cam = weight_softmax[class_idx].dot(feature_conv.reshape((nc, h*w)))
#         cam = cam.reshape(h, w)
#         cam = cam - np.min(cam)
#         cam_img = cam / np.max(cam)
#         cam_img = np.uint8(255 * cam_img)
#         output_cam.append(imresize(cam_img, size_upsample))
#     return output_cam

def returnTF():
# load the image transformer
    tf = trn.Compose([
        trn.Resize((224,224)),
        trn.ToTensor(),
        trn.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ])
    return tf


def load_model():
    # this model has a last conv feature map as 14x14

    model_file = 'wideresnet18_places365.pth.tar'
    if not os.access(model_file, os.W_OK):
        os.system('wget http://places2.csail.mit.edu/models_places365/' + model_file)
        os.system('wget https://raw.githubusercontent.com/csailvision/places365/master/wideresnet.py')

    import wideresnet
    model = wideresnet.resnet18(num_classes=365)
    checkpoint = torch.load(model_file, map_location=lambda storage, loc: storage)
    state_dict = {str.replace(k,'module.',''): v for k,v in checkpoint['state_dict'].items()}
    model.load_state_dict(state_dict)
    model.eval()



    # the following is deprecated, everything is migrated to python36

    ## if you encounter the UnicodeDecodeError when use python3 to load the model, add the following line will fix it. Thanks to @soravux
    #from functools import partial
    #import pickle
    #pickle.load = partial(pickle.load, encoding="latin1")
    #pickle.Unpickler = partial(pickle.Unpickler, encoding="latin1")
    #model = torch.load(model_file, map_location=lambda storage, loc: storage, pickle_module=pickle)

    model.eval()
    # hook the feature extractor
    features_names = ['layer4','avgpool'] # this is the last conv layer of the resnet
    for name in features_names:
        model._modules.get(name).register_forward_hook(hook_feature)
    return model

# %%
# load the labels
classes, labels_IO, labels_attribute, W_attribute = load_labels()

# load the model
features_blobs = []
model = load_model()

# load the transformer
tf = returnTF() # image transformer

# get the softmax weight
params = list(model.parameters())
weight_softmax = params[-2].data.numpy()
weight_softmax[weight_softmax<0] = 0

# %%
all_image_paths = list(image_dir.glob('*/*'))
all_image_paths = [str(path) for path in all_image_paths]
all_image_paths[:5]
# Out:
# ['/content/downloads/International Day of Women and Girls in Science/1.Celebrating-International-Day-of-Women-and-Girls-in-Science_OPTIMIZED-870x484.jpg',
#  '/content/downloads/National Family Medicine Board Review/1.hqdefault.jpg',
#  "/content/downloads/Drai's Live/1.32012851.jpg",
#  '/content/downloads/Redflint/1.web1_redflint-18_7537623.jpg',
#  '/content/downloads/International Day to End Obstetric Fistula/1.featured-image-index-sm.jpg']

# %%
len(all_image_paths)
# Some venue images are unavailable.
# Out:
# 1090

# %%
all_image_venues = list(image_dir.glob('*/*'))
all_image_venues = [str(path.parts[3]) for path in all_image_venues]

# %%
all_image_venues[:5]
# Out:
# ['International Day of Women and Girls in Science',
#  'National Family Medicine Board Review',
#  "Drai's Live",
#  'Redflint',
#  'International Day to End Obstetric Fistula']

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

def display_image(all_image_paths=all_image_paths,
                  all_image_venues=all_image_venues):

  for i in range(5):
    img_path = all_image_paths[i]
    img = mpimg.imread(img_path)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(img)
    plt.show()
  
    print(all_image_venues[i])

# %%
display_image()
# Out:
# International Day of Women and Girls in Science
# National Family Medicine Board Review
# Drai's Live
# Redflint
# International Day to End Obstetric Fistula

# %%
for i in range(len(all_image_paths)):
  # load the test image
  try:
    img = Image.open(all_image_paths[i])
    input_img = V(tf(img).unsqueeze(0))

    # forward pass
    logit = model.forward(input_img)
    h_x = F.softmax(logit, 1).data.squeeze()
    probs, idx = h_x.sort(0, True)
    probs = probs.numpy()
    idx = idx.numpy()

    # output the IO prediction
    io_image = np.mean(labels_IO[idx[:10]]) # vote for the indoor or outdoor
    if io_image < 0.5:
      venue.loc[venue.new_venue_name == all_image_venues[i], ['venue_type']] = 'indoor'
    else:
      venue.loc[venue.new_venue_name == all_image_venues[i], ['venue_type']] = 'outdoor'
      
  except Exception:
    print('Broken image', all_image_paths[i])
# Out:
# Broken image /content/downloads/World Autoimmune / Autoinflammatory Arthritis Day
# /usr/local/lib/python3.6/dist-packages/PIL/TiffImagePlugin.py:742: UserWarning: Corrupt EXIF data.  Expecting to read 4 bytes but only got 0.
#   warnings.warn(str(msg))
# Broken image /content/downloads/World Habitat Day/1.world-habitat-day_31012.jpg
# Broken image /content/downloads/National POW/MIA Recognition Day
# Broken image /content/downloads/Official Metal District/1.717966.jpg
# Broken image /content/downloads/EAR / OFAC Export Controls
# Broken image /content/downloads/Tu Bishvat/Tu B'Shevat
# Broken image /content/downloads/VFW Post 10047/1.12391873_1002005363190417_2283056170294629268_n.jpg
# Broken image /content/downloads/Cardio/Pulmonary Medicine for Primary Care
# Broken image /content/downloads/Shrove Tuesday/Mardi Gras
# Broken image /content/downloads/Kid's Hub - Las Vegas/1.Las-Vegas.jpg
# Broken image /content/downloads/Chanukah/Hanukkah (first day)
# Broken image /content/downloads/Diwali/Deepavali
# Broken image /content/downloads/Acres Underground / Cannabis Leadership Expo
# Broken image /content/downloads/East Las Vegas Community/Senior Center
# Broken image /content/downloads/Courtyard by Marriott Las Vegas Henderson/Green Valley

# %%
# Fill empty strings with nan
venue = venue.replace(r'^\s*$', np.nan, regex=True)

# %%
venue.head(10)
# Out:
#                                 venue_name  ...                          new_venue_name
# 0     Spa Ravella at Hilton Lake Las Vegas  ...    Spa Ravella at Hilton Lake Las Vegas
# 2   Green Valley Ranch Resort Spa & Casino  ...  Green Valley Ranch Resort Spa & Casino
# 3              Las Vegas Convention Center  ...             Las Vegas Convention Center
# 7              Henderson Convention Center  ...             Henderson Convention Center
# 9                       Night Owl Showroom  ...                      Night Owl Showroom
# 10                        Leif Erikson Day  ...                        Leif Erikson Day
# 11                    Hooters Casino Hotel  ...                    Hooters Casino Hotel
# 12                          World Post Day  ...                          World Post Day
# 14               Hispanic Museum of Nevada  ...               Hispanic Museum of Nevada
# 15                               V Theater  ...                               V Theater
#
# [10 rows x 4 columns]

# %%
venue[venue['venue_type'].isnull()]
# Out:
#                                              venue_name  ...                                    new_venue_name
# 18                                   Flamingo Las Vegas  ...                                Flamingo Las Vegas
# 114                                         Money Plays  ...                                       Money Plays
# 418                                      Scoundrels Pub  ...                                    Scoundrels Pub
# 1059   Unitarian Universalist Congregation of Las Vegas  ...  Unitarian Universalist Congregation of Las Vegas
# 1151                                      The Colosseum  ...                                     The Colosseum
# ...                                                 ...  ...                                               ...
# 88893                                     Indoor Ag-Con  ...                                     Indoor Ag-Con
# 89501                                Swiss Watch By JCK  ...                                Swiss Watch By JCK
# 93824                              Source Direct at ASD  ...                              Source Direct at ASD
# 94928                             Kid's Hub - Las Vegas  ...                             Kid's Hub - Las Vegas
# 95095                           Official Metal District  ...                           Official Metal District
#
# [67 rows x 4 columns]

# %% [markdown]
# # Some NLPs to fill NA's / reclassify

# %% [markdown]
# ## Top 150 tagging

# %%
# https://www.ling.upenn.edu/courses/Fall_2003/ling001/penn_treebank_pos.html
# Flatten into a list
tokens = venue.apply(lambda x: nltk.word_tokenize(x['venue_name']), axis=1).sum()
tags = nltk.pos_tag(tokens)

# %%
nouns = [token[0] for token in tags if token[1] == 'NNP']
frequency = nltk.FreqDist(nouns)
top_150 = frequency.most_common(150)

# %%
plt.figure(figsize=(20, 5))
plt.bar(range(len(top_150)), [val[1] for val in top_150], align='center')
plt.xticks(range(len(top_150)), [val[0] for val in top_150])
plt.xticks(rotation=90)
plt.title('Top 150 Tags in Venue Names, ' + CITY)
plt.savefig('Top 150 Tags in Venue Names, ' + CITY + '.jpg')
plt.show()

# %%
[val[0] for val in top_150]
# Out:
# ['Day',
#  'Vegas',
#  'Las',
#  'International',
#  'Casino',
#  'World',
#  'Hotel',
#  'Center',
#  'Conference',
#  'Club',
#  'Theater',
#  'National',
#  'Resort',
#  'Bar',
#  'Nightclub',
#  'Lounge',
#  'Expo',
#  'Theatre',
#  'Rock',
#  'Show',
#  'School',
#  'Park',
#  'Library',
#  'Convention',
#  'Showroom',
#  'Nevada',
#  'Spa',
#  'Comedy',
#  'Hard',
#  'Hall',
#  'Grand',
#  'Event',
#  'Church',
#  'Palace',
#  'Summit',
#  'Valley',
#  'MGM',
#  'Planet',
#  'Health',
#  'High',
#  'Caesars',
#  'Hollywood',
#  'Pool',
#  'Birthday',
#  'Victims',
#  'Festival',
#  'Henderson',
#  'Harrah',
#  'House',
#  'Country',
#  'South',
#  'Suites',
#  'Beach',
#  'University',
#  'United',
#  'Remembrance',
#  'Trade',
#  'Symposium',
#  'Ranch',
#  'New',
#  'Paris',
#  'Mirage',
#  'Rio',
#  'City',
#  'Encore',
#  'Arts',
#  'Women',
#  'Sports',
#  'Development',
#  'Ballroom',
#  'Care',
#  'Hilton',
#  'Bally',
#  'Bay',
#  'Wynn',
#  'Live',
#  'Grill',
#  'Palms',
#  'Cosmopolitan',
#  'Restaurant',
#  'West',
#  'Wine',
#  'Airport',
#  'Red',
#  'Summerlin',
#  'Annual',
#  'Village',
#  'Southern',
#  'Exhibition',
#  'Orthodox',
#  'Association',
#  'Awareness',
#  'Room',
#  'Global',
#  'Art',
#  'Museum',
#  'Events',
#  'Smith',
#  'Arena',
#  'Venetian',
#  'Mandalay',
#  'Point',
#  'Tropicana',
#  'Experience',
#  'Sahara',
#  'Cabaret',
#  'Spring',
#  'Hills',
#  'Campus',
#  'Station',
#  'Gold',
#  'Marriott',
#  'Inn',
#  'Square',
#  'Children',
#  'Human',
#  'Canyon',
#  'Law',
#  'Technology',
#  'Lake',
#  'Green',
#  'Night',
#  'Stratosphere',
#  'Viva',
#  'Westgate',
#  'Hustler',
#  'Orleans',
#  'Sunset',
#  'Marquee',
#  'Performing',
#  'Clark',
#  'District',
#  'Golf',
#  'Christian',
#  'Street',
#  'Studio',
#  'Academy',
#  'Nations',
#  'Hospital',
#  'Circus',
#  'War',
#  'Election',
#  'America',
#  'Science',
#  'Peace',
#  'Artisan',
#  'Music',
#  'Sunday',
#  'Monday',
#  'American']

# %%
# Many clubs/hotels
indoor_word_list = ['Casino', 'Hotel', 'Center', 'Conference', 'Club', 'Theater', \
                    'Bar', 'Resort', 'NightClub', 'Lounge', 'Expo', 'Theatre', \
                    'School', 'Show', 'Library', 'Convention', 'Showroom', 'Spa', \
                    'Hall', 'Church', 'Palace', 'Summit', 'MGM', 'Caesars', 'Harrah', \
                    'House', 'Suites', 'University', 'Ballroom', 'Hilton', 'Bally', \
                    'Wynn', 'Restaurant', 'Airport', 'Exhibition', 'Room', 'Museum', \
                    'Arena', 'Campus', 'Station', 'Marriott', 'Inn', 'Square', \
                    'Stratosphere', 'Westgate', 'Orleans', 'Marquee', 'Studio', \
                    'Academy', 'Hospital', 'Circus']
outdoor_word_list = ['Park', 'Beach', 'Lake', 'Golf', 'Day']
# 'Rock', 'Pool', 'Canyon', 'Street'

# %%
import inflect
# Obtain the plurals for the words
engine = inflect.engine() # case-sensitive
indoor_word_list_pl = [engine.plural(w.lower()) for w in indoor_word_list]
outdoor_word_list_pl = [engine.plural(w.lower()) for w in outdoor_word_list]

# %%
# Case-insensitive
indoor_list = [s.lower() for s in indoor_word_list + indoor_word_list_pl]
outdoor_list = [s.lower() for s in outdoor_word_list + outdoor_word_list_pl]

# %% [markdown]
# ## Reclassification

# %%
def compare_venue_type(df, indoor_list=indoor_list, outdoor_list=outdoor_list):
  # Compute count of substrings in indoor_list/outdoor_list
  # e.g., 'Spa Ravella at Hilton Lake Las Vegas' will have 
  # indoor_cnt = 2 and outdoor_cnt = 1, thus will be classified as 'indoor'
  indoor_cnt = sum(map(lambda x: x.lower() in indoor_list, df['new_venue_name'].split(' ')))
  outdoor_cnt = sum(map(lambda x: x.lower() in outdoor_list, df['new_venue_name'].split(' ')))
  
  return 'indoor' if indoor_cnt >= outdoor_cnt else 'outdoor'

# %%
venue['venue_type'] = venue.apply(compare_venue_type, axis=1)

# %%
venue.head(10)
# Out:
#                                 venue_name  ...                          new_venue_name
# 0     Spa Ravella at Hilton Lake Las Vegas  ...    Spa Ravella at Hilton Lake Las Vegas
# 2   Green Valley Ranch Resort Spa & Casino  ...  Green Valley Ranch Resort Spa & Casino
# 3              Las Vegas Convention Center  ...             Las Vegas Convention Center
# 7              Henderson Convention Center  ...             Henderson Convention Center
# 9                       Night Owl Showroom  ...                      Night Owl Showroom
# 10                        Leif Erikson Day  ...                        Leif Erikson Day
# 11                    Hooters Casino Hotel  ...                    Hooters Casino Hotel
# 12                          World Post Day  ...                          World Post Day
# 14               Hispanic Museum of Nevada  ...               Hispanic Museum of Nevada
# 15                               V Theater  ...                               V Theater
#
# [10 rows x 4 columns]

# %% [markdown]
# - What are left?

# %%
venue[venue['venue_type'].isnull()]
# Out:
# Empty DataFrame
# Columns: [venue_name, venue_id, venue_type, new_venue_name]
# Index: []

# %%
venue.venue_type.value_counts()
# Out:
# indoor     1011
# outdoor     256
# Name: venue_type, dtype: int64

# %% [markdown]
# - Most of the events have the type `indoor`. We will set it as default for the rest.

# %%
venue.loc[venue['venue_type'].isnull(),  ['venue_type']] = 'indoor'

# %% [markdown]
# # Output

# %%
venue.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1267 entries, 0 to 99006
# Data columns (total 4 columns):
# venue_name        1267 non-null object
# venue_id          1267 non-null int64
# venue_type        1267 non-null object
# new_venue_name    1267 non-null object
# dtypes: int64(1), object(3)
# memory usage: 49.5+ KB

# %%
venue.to_csv('events_' + CITY + '_venues.csv', index=False)

# %%
events_new = pd.merge(events, venue[['venue_id', 'venue_type']], 
                      on='venue_id',
                      how='left').drop('venue_id', 1)

# %%
events_new.shape
# Out:
# (99076, 21)

# %%
events_new.head(3)
# Out:
#                    id  ... venue_type
# 0  QMkyB7YCXgZQqsWB8e  ...     indoor
# 1        nvABpR9LXwwk  ...        NaN
# 2        PlVJdqVPJzXm  ...     indoor
#
# [3 rows x 21 columns]

# %%
events_new.category.unique()
# Out:
# array(['community', 'conferences', 'expos', 'observances',
#        'performing-arts', 'concerts', 'festivals', 'sports', 'disasters',
#        'airport-delays', 'public-holidays', 'daylight-savings',
#        'politics', 'severe-weather', 'school-holidays', 'terror'],
#       dtype=object)

# %%
events_new.to_csv('events_' + CITY + '.csv', index=False)

# %%
from google.colab import files

# %%
files.download('Top 150 Tags in Venue Names, ' + CITY + '.jpg')

# %%
files.download('events_' + CITY + '_venues.csv')

# %%
files.download('events_' + CITY + '.csv')

# %%
output_zip = 'venue_images_' + CITY + '.zip'

# %%
# !zip -r $output_zip $image_dir
# Out:
#   adding: content/downloads/ (stored 0%)
#   adding: content/downloads/International Day of Women and Girls in Science/ (stored 0%)
#   adding: content/downloads/International Day of Women and Girls in Science/1.Celebrating-International-Day-of-Women-and-Girls-in-Science_OPTIMIZED-870x484.jpg (deflated 1%)
#   adding: content/downloads/National Family Medicine Board Review/ (stored 0%)
#   adding: content/downloads/National Family Medicine Board Review/1.hqdefault.jpg (deflated 3%)
#   adding: content/downloads/Drai's Live/ (stored 0%)
#   adding: content/downloads/Drai's Live/1.32012851.jpg (deflated 1%)
#   adding: content/downloads/Redflint/ (stored 0%)
#   adding: content/downloads/Redflint/1.web1_redflint-18_7537623.jpg (deflated 0%)
#   adding: content/downloads/International Day to End Obstetric Fistula/ (stored 0%)
#   adding: content/downloads/International Day to End Obstetric Fistula/1.featured-image-index-sm.jpg (deflated 9%)
#   adding: content/downloads/PBS Technology Conference/ (stored 0%)
#   adding: content/downloads/PBS Technology Conference/1.RTR3P77N-1024x656.jpg (deflated 1%)
#   adding: content/downloads/Multi-Unit Restaurant Technology Conference/ (stored 0%)
#   adding: content/downloads/Multi-Unit Restaurant Technology Conference/1.Murtec19_Teaser.jpg (deflated 2%)
#   adding: content/downloads/Stoller's Current Issues of Magnetic Resonance Imaging In Orthopaedics and Sports Medicine/ (stored 0%)
#   adding: content/downloads/Stoller's Current Issues of Magnetic Resonance Imaging In Orthopaedics and Sports Medicine/1.514fgyZ8NKL._SR600%2C315_PIWhiteStrip%2CBottomLeft%2C0%2C35_PIAmznPrime%2CBottomLeft%2C0%2C-5_PIStarRatingFOURANDHALF%2CBottomLeft%2C360%2C-6_SR600%2C315_ZA(15%20Reviews)%2C445%2C291%2C400%2C400%2Carial%2C12%2C4%2C0%2C0%2C5_SCLZZZZZZZ_.jpg (deflated 15%)
#   adding: content/downloads/Kansas Day/ (stored 0%)
#   adding: content/downloads/Kansas Day/1.National-Kansas-Day-March-15-1024x512.jpg (deflated 3%)
#   adding: content/downloads/Michael Jackson ONE/ (stored 0%)
#   adding: content/downloads/Michael Jackson ONE/1.michael-jackson-one-act-dirty-diana.jpg (deflated 0%)
#   adding: content/downloads/Tahiti Village Resort/ (stored 0%)
#   adding: content/downloads/TPC Summerlin/ (stored 0%)
#   adding: content/downloads/TPC Summerlin/1.15.jpg (deflated 0%)
#   adding: content/downloads/Suncoast Hotel & Casino/ (stored 0%)
#   adding: content/downloads/Suncoast Hotel & Casino/1.15042225.jpg (deflated 1%)
#   adding: content/downloads/North Las Vegas City Hall/ (stored 0%)
#   adding: content/downloads/North Las Vegas City Hall/1.CityHallNight_750.jpg (deflated 1%)
#   adding: content/downloads/Rio Convention Center/ (stored 0%)
#   adding: content/downloads/Rio Convention Center/1.the-main-auditorium.jpg (deflated 0%)
#   adding: content/downloads/Double Down Saloon/ (stored 0%)
#   adding: content/downloads/Double Down Saloon/1.10521034_web1_crop-vv-moss-may15-18bt04.jpg (deflated 0%)
#   adding: content/downloads/MRI Of The Head And Spine National Symposium/ (stored 0%)
#   adding: content/downloads/MRI Of The Head And Spine National Symposium/1.Fonar-symposium-2013.jpg (deflated 1%)
#   adding: content/downloads/Improv Comedy Club -  Harrah's Hotel/ (stored 0%)
#   adding: content/downloads/Improv Comedy Club -  Harrah's Hotel/1.the-marquee.jpg (deflated 0%)
#   adding: content/downloads/Keep Memory Alive Event Center/ (stored 0%)
#   adding: content/downloads/Keep Memory Alive Event Center/1.original_Lou-Ruvo-keep-memoryalive0.jpg (deflated 0%)
#   adding: content/downloads/OFFICIAL MUSIC DISTRICT THEATRE/ (stored 0%)
#   adding: content/downloads/OFFICIAL MUSIC DISTRICT THEATRE/1.https%3A%2F%2Fcdn.evbuc.com%2Fimages%2F52365822%2F185596842872%2F1%2Foriginal.jpg (deflated 0%)
#   adding: content/downloads/Nevada Day/ (stored 0%)
#   adding: content/downloads/Nevada Day/1.National-Nevada-Day-March-29-2-1024x512.jpg (deflated 0%)
#   adding: content/downloads/Wright Brothers Day/ (stored 0%)
#   adding: content/downloads/Wright Brothers Day/1.Wright-Brothers.jpg (deflated 0%)
#   adding: content/downloads/David Copperfield/ (stored 0%)
#   adding: content/downloads/David Copperfield/1.DCatAGT.JPG (deflated 0%)
#   adding: content/downloads/International Migrants Day/ (stored 0%)
#   adding: content/downloads/International Migrants Day/1.5.CallAction-650x420.jpg (deflated 0%)
#   adding: content/downloads/International Day of Solidarity with Detained and Missing Staff Members/ (stored 0%)
#   adding: content/downloads/International Day of Solidarity with Detained and Missing Staff Members/1.elimination-racial-discrimination.jpg (deflated 1%)
#   adding: content/downloads/Take our Daughters and Sons to Work Day/ (stored 0%)
#   adding: content/downloads/Take our Daughters and Sons to Work Day/1.TakeKidsToWork_16x9_hpMain_16x9_992.jpg (deflated 1%)
#   adding: content/downloads/Colonnade 14/ (stored 0%)
#   adding: content/downloads/Colonnade 14/1.-visit_to_Regal_Colonnade_-20000000008126688-500x375.jpg (deflated 1%)
#   adding: content/downloads/Greenspun Hall Auditorium/ (stored 0%)
#   adding: content/downloads/Greenspun Hall Auditorium/1.UrbanAffairs-GreenspunHallAuditorium-D66750-13_0.jpg (deflated 0%)
#   adding: content/downloads/Mandalay Bay Events Center/ (stored 0%)
#   adding: content/downloads/Mandalay Bay Events Center/1.10614530_web1_bkl-aces_052518ev_006.jpg (deflated 1%)
#   adding: content/downloads/Leif Erikson Day/ (stored 0%)
#   adding: content/downloads/Count's Vamp'd Rock Bar & Grill/ (stored 0%)
#   adding: content/downloads/Count's Vamp'd Rock Bar & Grill/1.count-vamp-d-bar-grill.jpg (deflated 0%)
#   adding: content/downloads/December Solstice/ (stored 0%)
#   adding: content/downloads/DSE/ (stored 0%)
#   adding: content/downloads/DSE/1.scmpost_08apr13_ns_dse2_c3.jpg (deflated 0%)
#   adding: content/downloads/Marine Corps Birthday/ (stored 0%)
#   adding: content/downloads/Connections/ (stored 0%)
#   adding: content/downloads/Connections/1.the-power-of-connections-883x432.jpg (deflated 7%)
#   adding: content/downloads/International Day for the Elimination of Racial Discrimination/ (stored 0%)
#   adding: content/downloads/International Day for the Elimination of Racial Discrimination/1.EliminateRacialDiscriminationDayWeb.jpg (deflated 9%)
#   adding: content/downloads/International Congress on Nosocomial and Healthcare associated Infections/ (stored 0%)
#   adding: content/downloads/International Congress on Nosocomial and Healthcare associated Infections/1.nosocomialinfections2017-50531.jpg (deflated 1%)
#   adding: content/downloads/International Programmers' Day/ (stored 0%)
#   adding: content/downloads/Las Vegas Review Journal/ (stored 0%)
#   adding: content/downloads/Las Vegas Review Journal/1.13088166_web1_ccdcweb.jpg (deflated 0%)
#   adding: content/downloads/Central Church/ (stored 0%)
#   adding: content/downloads/Central Church/1.CentralChurch-7.jpg (deflated 1%)
#   adding: content/downloads/Adobe ColdFusion Summit/ (stored 0%)
#   adding: content/downloads/Locals Coins Show/ (stored 0%)
#   adding: content/downloads/Locals Coins Show/1.Coin-Show-Bourse-2011-56a179825f9b58b7d0bfa736.jpg (deflated 0%)
#   adding: content/downloads/MGM Resorts International/ (stored 0%)
#   adding: content/downloads/MGM Resorts International/1.mgm-bellagio-night.jpg (deflated 1%)
#   adding: content/downloads/Priscilla Fowler Fine Art/ (stored 0%)
#   adding: content/downloads/Priscilla Fowler Fine Art/1.getlstd-property-photo.jpg (deflated 0%)
#   adding: content/downloads/Opium Theatre at the Cosmopolitan of Las Vegas/ (stored 0%)
#   adding: content/downloads/Opium Theatre at the Cosmopolitan of Las Vegas/1.10386131_web1_standing-ovation-at-galactic-premeire-of-opium-at-the-cosmopolitan-of-las-vegas_credit-al-powers-for-spiegelworld.jpg (deflated 1%)
#   adding: content/downloads/World Autoimmune / (stored 0%)
#   adding: content/downloads/World Autoimmune / Autoinflammatory Arthritis Day/ (stored 0%)
#   adding: content/downloads/International Day of Rural Women/ (stored 0%)
#   adding: content/downloads/International Day of Rural Women/1.International-Day-of-Rural-Women.jpg (deflated 0%)
#   adding: content/downloads/Red Rock Fertility Center/ (stored 0%)
#   adding: content/downloads/Red Rock Fertility Center/1.o.jpg (deflated 2%)
#   adding: content/downloads/International Bowl Expo/ (stored 0%)
#   adding: content/downloads/International Bowl Expo/1.ExhibitWithUsCollage.jpg (deflated 1%)
#   adding: content/downloads/Container Park/ (stored 0%)
#   adding: content/downloads/Container Park/1.Container-Park__2018_Container_Park_Entrance.jpg (deflated 0%)
#   adding: content/downloads/Reggae Beach Club/ (stored 0%)
#   adding: content/downloads/Reggae Beach Club/1.reggae-beach-bar-grill.jpg (deflated 0%)
#   adding: content/downloads/The Axis Theater Las Vegas Planet Hollywood/ (stored 0%)
#   adding: content/downloads/The Axis Theater Las Vegas Planet Hollywood/1.1569879534435.jpg (deflated 0%)
#   adding: content/downloads/EOS Fitness Las Vegas Sahara Gym/ (stored 0%)
#   adding: content/downloads/EOS Fitness Las Vegas Sahara Gym/1.348s.jpg (deflated 0%)
#   adding: content/downloads/International Business Conference/ (stored 0%)
#   adding: content/downloads/Green Valley Ranch/ (stored 0%)
#   adding: content/downloads/Revenue Cycle Solutions Summit/ (stored 0%)
#   adding: content/downloads/Revenue Cycle Solutions Summit/1.HIMSS19-Revenue-Cycle-Solutions-Summit.jpg (deflated 0%)
#   adding: content/downloads/Desert Breeze Park/ (stored 0%)
#   adding: content/downloads/Desert Breeze Park/1.image.jpg (deflated 0%)
#   adding: content/downloads/Syncis/ (stored 0%)
#   adding: content/downloads/Waves Las Vegas/ (stored 0%)
#   adding: content/downloads/Waves Las Vegas/1.the-wave.jpg (deflated 0%)
#   adding: content/downloads/Keller Williams Southern Nevada/ (stored 0%)
#   adding: content/downloads/Keller Williams Southern Nevada/1.web1_dscf1224.jpg (deflated 0%)
#   adding: content/downloads/1 Oak Las Vegas at the Mirage Hotel and Casino/ (stored 0%)
#   adding: content/downloads/1 Oak Las Vegas at the Mirage Hotel and Casino/1.1-OAK-Las-Vegas-bottle-service-Mirage.jpg (deflated 1%)
#   adding: content/downloads/Maha Shivaratri/ (stored 0%)
#   adding: content/downloads/Maha Shivaratri/1.bangalore_shiva.jpg (deflated 0%)
#   adding: content/downloads/Public Service Day/ (stored 0%)
#   adding: content/downloads/Public Service Day/1.Public-Sector-Group.jpg (deflated 0%)
#   adding: content/downloads/International Day of Happiness/ (stored 0%)
#   adding: content/downloads/International Day of Happiness/1.happiness-lead-photo_759_pixabay.jpg (deflated 3%)
#   adding: content/downloads/World Migratory Bird Day/ (stored 0%)
#   adding: content/downloads/World Migratory Bird Day/1.wmbd-2019_banner-front.jpg (deflated 11%)
#   adding: content/downloads/AGTA GemFair/ (stored 0%)
#   adding: content/downloads/AGTA GemFair/1.20171130_Antique-show.jpg (deflated 3%)
#   adding: content/downloads/Canyon Club At Four Queens/ (stored 0%)
#   adding: content/downloads/Canyon Club At Four Queens/1.slide6.jpg (deflated 0%)
#   adding: content/downloads/Love Theatre at The Mirage Hotel and Casino/ (stored 0%)
#   adding: content/downloads/Love Theatre at The Mirage Hotel and Casino/1.anonymous-20190509040946.jpg (deflated 0%)
#   adding: content/downloads/Global Day of Parents/ (stored 0%)
#   adding: content/downloads/Moapa River Indian Reservation/ (stored 0%)
#   adding: content/downloads/Moapa River Indian Reservation/1.5105a291-3767-41bc-ab41-37acc13c9fc2.jpg (deflated 5%)
#   adding: content/downloads/The Chxrch/ (stored 0%)
#   adding: content/downloads/The Chxrch/1.Slaves2018-2758-1024x683.jpg (deflated 0%)
#   adding: content/downloads/Fort Cheyenne Event Center/ (stored 0%)
#   adding: content/downloads/Fort Cheyenne Event Center/1.DSCN1509_320566f2-5056-b365-ab82906ae7e80efa.jpg (deflated 5%)
#   adding: content/downloads/The Linq Hotel & Casino/ (stored 0%)
#   adding: content/downloads/The Linq Hotel & Casino/1.37337776.jpg (deflated 2%)
#   adding: content/downloads/Exodus Festival Las Vegas - Labour Day Weekend/ (stored 0%)
#   adding: content/downloads/Exodus Festival Las Vegas - Labour Day Weekend/1.Vegas-Pool-Party-Header-696x446-2.jpg (deflated 0%)
#   adding: content/downloads/National Aviation Day/ (stored 0%)
#   adding: content/downloads/National Aviation Day/1.National-Aviation-Day-August-19.jpg (deflated 5%)
#   adding: content/downloads/New Year's Eve/ (stored 0%)
#   adding: content/downloads/New Year's Eve/1.New-Years-Eve0_f5f19cc4-bff1-1500-863a6b1ac29af142.jpg (deflated 0%)
#   adding: content/downloads/Calvary Chapel Las Vegas/ (stored 0%)
#   adding: content/downloads/Calvary Chapel Las Vegas/1.10891387_web1_IMAG0808.jpg (deflated 1%)
#   adding: content/downloads/Marjorie Barrick Museum/ (stored 0%)
#   adding: content/downloads/Marjorie Barrick Museum/1.barrick_museum-D71125_12.jpg (deflated 0%)
#   adding: content/downloads/Bally's Las Vegas Hotel & Casino (Skyview 5)/ (stored 0%)
#   adding: content/downloads/Bally's Las Vegas Hotel & Casino (Skyview 5)/1.resort-studio-suite.jpg (deflated 0%)
#   adding: content/downloads/Springs Preserve/ (stored 0%)
#   adding: content/downloads/Springs Preserve/1.the-springs-preserve.jpg (deflated 0%)
#   adding: content/downloads/Foundation Room Rooftop Nightclub Free entry!/ (stored 0%)
#   adding: content/downloads/Foundation Room Rooftop Nightclub Free entry!/1.Foundation-Room-Las-Vegas-Guest-List.jpg (deflated 13%)
#   adding: content/downloads/Chateau/ (stored 0%)
#   adding: content/downloads/Chateau/1.cduc-chateauexterior-3.jpg (deflated 1%)
#   adding: content/downloads/Yom Ha'atzmaut/ (stored 0%)
#   adding: content/downloads/Yom Ha'atzmaut/1.Ashkelon-kids-YH-flash90.jpg (deflated 2%)
#   adding: content/downloads/Chi Showroom - Planet Hollywood/ (stored 0%)
#   adding: content/downloads/Chi Showroom - Planet Hollywood/1.faccd23d9d2be4047b2dab91a62e15fc.jpg (deflated 0%)
#   adding: content/downloads/International Day in Support of Victims of Torture/ (stored 0%)
#   adding: content/downloads/International Day in Support of Victims of Torture/1.196451_International_Day_in_Support_of_Victims_of_Torture_Event_Stop_Torture_Campaign-e1474275939560-1425x900-1024x647.jpg (deflated 0%)
#   adding: content/downloads/National Guard Birthday/ (stored 0%)
#   adding: content/downloads/National Guard Birthday/1.national-guard-birthday-lp-header-2017.jpg (deflated 1%)
#   adding: content/downloads/Summerlin Hospital/ (stored 0%)
#   adding: content/downloads/Summerlin Hospital/1.about-summerlin-hospital-medical-center.jpg (deflated 1%)
#   adding: content/downloads/Humana - Summerlin/ (stored 0%)
#   adding: content/downloads/Humana - Summerlin/1.12502908_web1_Photo-1.jpg (deflated 1%)
#   adding: content/downloads/Legends Sports Bar & Grill/ (stored 0%)
#   adding: content/downloads/Legends Sports Bar & Grill/1.legends-sports-bar.jpg (deflated 0%)
#   adding: content/downloads/Current Psychiatry Conference/ (stored 0%)
#   adding: content/downloads/Current Psychiatry Conference/1.aacp_2018.jpg (deflated 1%)
#   adding: content/downloads/Trinity Sunday/ (stored 0%)
#   adding: content/downloads/Trinity Sunday/1.shutterstock_122655007-660x350.jpg (deflated 0%)
#   adding: content/downloads/Hard Rock Hotel & Casino - Vinyl/ (stored 0%)
#   adding: content/downloads/Hard Rock Hotel & Casino - Vinyl/1.vinyl-slide1.jpg (deflated 6%)
#   adding: content/downloads/International Conference on Internet Computing and Internet of Things/ (stored 0%)
#   adding: content/downloads/International Conference on Internet Computing and Internet of Things/1.98fba2a2-e4d2-42ba-8aaf-ba7b7cab73dc_Computing-and-Internet-of-Things.jpg (deflated 0%)
#   adding: content/downloads/Club 2100/ (stored 0%)
#   adding: content/downloads/Kracker Boxx Bar/ (stored 0%)
#   adding: content/downloads/Kracker Boxx Bar/1.Kracker-Boxx-Bar-1.jpg (deflated 0%)
#   adding: content/downloads/Annual National Psychopharmacology Update Conference/ (stored 0%)
#   adding: content/downloads/Jin's Club/ (stored 0%)
#   adding: content/downloads/Jin's Club/1.o.jpg (deflated 1%)
#   adding: content/downloads/XS Nightclub - Wynn Las Vegas/ (stored 0%)
#   adding: content/downloads/XS Nightclub - Wynn Las Vegas/1.XS-Nightclub__2018_XS-The-Nightclub-crop---photo-by-Barbara-Kraft.jpg (deflated 0%)
#   adding: content/downloads/Simchat Torah/ (stored 0%)
#   adding: content/downloads/Simchat Torah/1.ZjLb9432652.jpg (deflated 1%)
#   adding: content/downloads/Cosmopolitan of Las Vegas - STK/ (stored 0%)
#   adding: content/downloads/Cosmopolitan of Las Vegas - STK/1.stkdining-56a43e4b5f9b58b7d0d5fe9d.jpg (deflated 0%)
#   adding: content/downloads/Spring Valley Library/ (stored 0%)
#   adding: content/downloads/International Day against Nuclear Tests/ (stored 0%)
#   adding: content/downloads/International Day against Nuclear Tests/1.International-Day-Against-Nuclear-Testing-August-29-1.jpg (deflated 4%)
#   adding: content/downloads/V2 Theater at Planet Hollywood Resort and Casino/ (stored 0%)
#   adding: content/downloads/North Las Vegas Airport/ (stored 0%)
#   adding: content/downloads/North Las Vegas Airport/1.Cirrus_SR22_KVGT_%283334257735%29.jpg (deflated 2%)
#   adding: content/downloads/Larry Flynt's Hustler Club/ (stored 0%)
#   adding: content/downloads/Larry Flynt's Hustler Club/1.larry-flint-hustler-las-vegas-1024x567.jpg (deflated 0%)
#   adding: content/downloads/Retail Realm Technology Conference/ (stored 0%)
#   adding: content/downloads/V3 Theater at Planet Hollywood Resort and Casino/ (stored 0%)
#   adding: content/downloads/V3 Theater at Planet Hollywood Resort and Casino/1.1569879534435.jpg (deflated 0%)
#   adding: content/downloads/Exposition and Conference/ (stored 0%)
#   adding: content/downloads/Exposition and Conference/1.1345508757.jpg (deflated 0%)
#   adding: content/downloads/Conversion Conference Las Vegas/ (stored 0%)
#   adding: content/downloads/Conversion Conference Las Vegas/1.13391531_10153560883522882_5525539981151146861_o-1024x684.jpg (deflated 0%)
#   adding: content/downloads/Fiesta Henderson/ (stored 0%)
#   adding: content/downloads/Fiesta Henderson/1.FH-WelcomeBackground.jpg (deflated 2%)
#   adding: content/downloads/National Ergonomics Conference and ErgoExpo/ (stored 0%)
#   adding: content/downloads/National Ergonomics Conference and ErgoExpo/1.event-image-848a884c-e309-4bd8-b827-1432773e8295.jpg (deflated 3%)
#   adding: content/downloads/Silhouette Bridal/ (stored 0%)
#   adding: content/downloads/Silhouette Bridal/1.bridal.jpg (deflated 7%)
#   adding: content/downloads/The Griffin/ (stored 0%)
#   adding: content/downloads/The Griffin/1.image.jpg (deflated 0%)
#   adding: content/downloads/Strawberri Taylor presents : Sugar Brown Burlesque Bad & Bougie Comedy/ (stored 0%)
#   adding: content/downloads/Strawberri Taylor presents : Sugar Brown Burlesque Bad & Bougie Comedy/1.https%3A%2F%2Fcdn.evbuc.com%2Fimages%2F44136447%2F1976632244%2F1%2Foriginal.jpg (deflated 1%)
#   adding: content/downloads/Tropicana Hotel - Tropicana Theater/ (stored 0%)
#   adding: content/downloads/Tropicana Hotel - Tropicana Theater/1.Trop-Showroom-Hero.jpg (deflated 0%)
#   adding: content/downloads/ASPS Aesthetica/ (stored 0%)
#   adding: content/downloads/ASPS Aesthetica/1.MOD-74213_DrPatrickKSullivan.jpg (deflated 0%)
#   adding: content/downloads/Angel Park Golf Club/ (stored 0%)
#   adding: content/downloads/Angel Park Golf Club/1.original_angel-park-golf.jpg (deflated 1%)
#   adding: content/downloads/Stoney's Rockin' Country/ (stored 0%)
#   adding: content/downloads/Stoney's Rockin' Country/1.20180412-THF_8136-e1571224344756.jpg (deflated 11%)
#   adding: content/downloads/Las Vegas Library/ (stored 0%)
#   adding: content/downloads/Las Vegas Library/1.cc.jpg (deflated 1%)
#   adding: content/downloads/EDC/ (stored 0%)
#   adding: content/downloads/Thomas and Mack Moot Court/ (stored 0%)
#   adding: content/downloads/Thomas and Mack Moot Court/1.MCB-D65707_13.jpg (deflated 1%)
#   adding: content/downloads/Bodies…The Exhibition/ (stored 0%)
#   adding: content/downloads/Bodies…The Exhibition/1._101051914_b564a40c-6046-47a8-a1cb-3004a307f93b.jpg (deflated 0%)
#   adding: content/downloads/American Dream U/ (stored 0%)
#   adding: content/downloads/American Dream U/1.727682734_780x439.jpg (deflated 0%)
#   adding: content/downloads/St. Elizabeth Ann Seton Catholic Church/ (stored 0%)
#   adding: content/downloads/St. Elizabeth Ann Seton Catholic Church/1.DT00004-1.jpg (deflated 2%)
#   adding: content/downloads/COUTURE/ (stored 0%)
#   adding: content/downloads/COUTURE/1.26tmag-couture-rules-jumbo.jpg (deflated 0%)
#   adding: content/downloads/Keller Williams Realty Las Vegas/ (stored 0%)
#   adding: content/downloads/Keller Williams Realty Las Vegas/1.6.edited-1024x683.jpg (deflated 0%)
#   adding: content/downloads/T-Mobile Arena/ (stored 0%)
#   adding: content/downloads/T-Mobile Arena/1.photo0jpg.jpg (deflated 0%)
#   adding: content/downloads/AICPA Controllers Workshop/ (stored 0%)
#   adding: content/downloads/AICPA Controllers Workshop/1.EF-A48YWsAMaEiH.jpg (deflated 4%)
#   adding: content/downloads/Royal Resort/ (stored 0%)
#   adding: content/downloads/Royal Resort/1.29734886.jpg (deflated 0%)
#   adding: content/downloads/Aliante Casino + Hotel + Spa/ (stored 0%)
#   adding: content/downloads/Aliante Casino + Hotel + Spa/1.aliante-gallery-exterior-full.jpg (deflated 2%)
#   adding: content/downloads/The Space L.V./ (stored 0%)
#   adding: content/downloads/The Space L.V./1.web1_copy_img_6985_7997511.jpg (deflated 0%)
#   adding: content/downloads/Keller Williams Realty Southwest/ (stored 0%)
#   adding: content/downloads/Keller Williams Realty Southwest/1.l.jpg (deflated 1%)
#   adding: content/downloads/The Martini/ (stored 0%)
#   adding: content/downloads/Bassrush Massive - Las Vegas/ (stored 0%)
#   adding: content/downloads/Summerlin Community Baptist Church/ (stored 0%)
#   adding: content/downloads/Summerlin Community Baptist Church/1.o.jpg (deflated 0%)
#   adding: content/downloads/Hilton Garden Inn Las Vegas Strip South/ (stored 0%)
#   adding: content/downloads/Hilton Garden Inn Las Vegas Strip South/1.lasgigi-03.jpg (deflated 1%)
#   adding: content/downloads/World Environment Day/ (stored 0%)
#   adding: content/downloads/World Environment Day/1.World-Environment-Day-HD-wallpaper.jpg (deflated 0%)
#   adding: content/downloads/JEWEL Nightclub/ (stored 0%)
#   adding: content/downloads/JEWEL Nightclub/1.Jewel-Nightclub-Las-Vegas-2.jpg (deflated 0%)
#   adding: content/downloads/Eid al-Adha/ (stored 0%)
#   adding: content/downloads/The Gossy Room at Caesars Palace/ (stored 0%)
#   adding: content/downloads/The Gossy Room at Caesars Palace/1.the-gossy-room-at-caesars-palace_las-vegas_04-09-13_14_51644956eaa8b.jpg (deflated 0%)
#   adding: content/downloads/Police  Fire  EMS  and Municipal Employee Pension & Benefits Seminar/ (stored 0%)
#   adding: content/downloads/Police  Fire  EMS  and Municipal Employee Pension & Benefits Seminar/1.DU0l9UWWAAEoFBL.jpg (deflated 3%)
#   adding: content/downloads/Enchanted Forest Reiki Center/ (stored 0%)
#   adding: content/downloads/Enchanted Forest Reiki Center/1.web1_ev-sw-enchanted-oct30-14-1-cmyk.jpg (deflated 0%)
#   adding: content/downloads/International Day of Zero Tolerance for Female Genital Mutilation/ (stored 0%)
#   adding: content/downloads/International Day of Zero Tolerance for Female Genital Mutilation/1.banner_international-day-zero-tolerance-fgmc-14.jpg (deflated 1%)
#   adding: content/downloads/Credit Union Call Center Conference/ (stored 0%)
#   adding: content/downloads/Credit Union Call Center Conference/1.header_new_7.jpg (deflated 3%)
#   adding: content/downloads/D-Day/ (stored 0%)
#   adding: content/downloads/D-Day/1.eisenhower-knew-the-importance-of-d-day-for-an-allied-victorys-featured-photo.jpg (deflated 1%)
#   adding: content/downloads/House of Blues - Restaurant & Bar/ (stored 0%)
#   adding: content/downloads/House of Blues - Restaurant & Bar/1.house-of-blues-restaurant-00.jpg (deflated 0%)
#   adding: content/downloads/Annual Interdisciplinary Breast Center Conference/ (stored 0%)
#   adding: content/downloads/Annual Interdisciplinary Breast Center Conference/1.highlights_2019.jpg (deflated 0%)
#   adding: content/downloads/Artisan Craft Festival: Springs Preserve/ (stored 0%)
#   adding: content/downloads/Artisan Craft Festival: Springs Preserve/1.web1_springfling_030517eb_010.jpg (deflated 0%)
#   adding: content/downloads/Friday the 13th/ (stored 0%)
#   adding: content/downloads/Friday the 13th/1.jason_friday-the-13th_gallery_5c4b88a2d8be2.jpg (deflated 1%)
#   adding: content/downloads/Coca-Cola Store Las Vegas/ (stored 0%)
#   adding: content/downloads/Coca-Cola Store Las Vegas/1.coca-cola-vegas-620x348.jpg (deflated 1%)
#   adding: content/downloads/World Cerebral Palsy Day/ (stored 0%)
#   adding: content/downloads/World Cerebral Palsy Day/1.world-cerebral-palsy-day.jpg (deflated 0%)
#   adding: content/downloads/World Day Against Child Labour/ (stored 0%)
#   adding: content/downloads/World Day Against Child Labour/1.child-labour.jpg (deflated 0%)
#   adding: content/downloads/Brio Tuscan Grille/ (stored 0%)
#   adding: content/downloads/World Toilet Day/ (stored 0%)
#   adding: content/downloads/World Toilet Day/1.WorldToiletDaysize-750x420.jpg (deflated 12%)
#   adding: content/downloads/E-String/ (stored 0%)
#   adding: content/downloads/E-String/1.classic-5.jpg (deflated 1%)
#   adding: content/downloads/Sapphire Las Vegas Gentlemen's Club/ (stored 0%)
#   adding: content/downloads/Sapphire Las Vegas Gentlemen's Club/1.club_img_lg_03.jpg (deflated 0%)
#   adding: content/downloads/Kaos Nightclub/ (stored 0%)
#   adding: content/downloads/Kaos Nightclub/1.12941531_web1_webKAOS-OPENING_040519cs_001.jpg (deflated 0%)
#   adding: content/downloads/Capstone Brokerage  Inc./ (stored 0%)
#   adding: content/downloads/Capstone Brokerage  Inc./1.capstone-brokerage-office-space.jpg (deflated 1%)
#   adding: content/downloads/New York-New York Hotel & Casino - Nine Fine Irishmen/ (stored 0%)
#   adding: content/downloads/International Day of Non-Violence/ (stored 0%)
#   adding: content/downloads/International Day of Non-Violence/1.International-Day-of-Non-Violence-October-2nd-1.jpg (deflated 5%)
#   adding: content/downloads/Emergency Ultrasound Course/ (stored 0%)
#   adding: content/downloads/Emergency Ultrasound Course/1.introdesign.jpg (deflated 3%)
#   adding: content/downloads/Nellis Air Force Base/ (stored 0%)
#   adding: content/downloads/Nellis Air Force Base/1.141108-F-OS776-225.JPG (deflated 1%)
#   adding: content/downloads/Eiffel Tower Viewing Deck at Paris Las Vegas/ (stored 0%)
#   adding: content/downloads/Eiffel Tower Viewing Deck at Paris Las Vegas/1.63.jpg (deflated 0%)
#   adding: content/downloads/Day After Thanksgiving/ (stored 0%)
#   adding: content/downloads/Day After Thanksgiving/1.Day-After.jpg (deflated 4%)
#   adding: content/downloads/Cashman Center/ (stored 0%)
#   adding: content/downloads/Cashman Center/1.9738980_web1_cashman-lv_aerials_092616bl_373.jpg (deflated 0%)
#   adding: content/downloads/International Day of Human Space Flight/ (stored 0%)
#   adding: content/downloads/International Day of Human Space Flight/1.hp_intl_day_human_spaceflight.jpg (deflated 0%)
#   adding: content/downloads/Veterans Day/ (stored 0%)
#   adding: content/downloads/Veterans Day/1.veterans-day-640x514.jpg (deflated 0%)
#   adding: content/downloads/Gold Mine Tavern/ (stored 0%)
#   adding: content/downloads/Gold Mine Tavern/1.gold-mine.jpg (deflated 0%)
#   adding: content/downloads/Classic Jewel/ (stored 0%)
#   adding: content/downloads/Classic Jewel/1.web1_juhl_063015cs_006_2.jpg (deflated 0%)
#   adding: content/downloads/NPI Conference/ (stored 0%)
#   adding: content/downloads/NPI Conference/1.Matthew-Parrot-Interview.jpg (deflated 15%)
#   adding: content/downloads/Multi-State Salinity Coalition Salinity Summit/ (stored 0%)
#   adding: content/downloads/Multi-State Salinity Coalition Salinity Summit/1.Canal-Water-MSSC.jpg (deflated 1%)
#   adding: content/downloads/InStyle Flooring & Designs Showroom/ (stored 0%)
#   adding: content/downloads/InStyle Flooring & Designs Showroom/1.slider-landscape3-1200x525.jpg (deflated 2%)
#   adding: content/downloads/Caesars Palace - Spiegeltent/ (stored 0%)
#   adding: content/downloads/Caesars Palace - Spiegeltent/1.original_SpiegelTent0.jpg (deflated 0%)
#   adding: content/downloads/The Packaging Conference/ (stored 0%)
#   adding: content/downloads/The Packaging Conference/1.header-image.jpg (deflated 5%)
#   adding: content/downloads/Navy Birthday/ (stored 0%)
#   adding: content/downloads/Navy Birthday/1.Navy_Bday_Blog-2-660x330.jpg (deflated 0%)
#   adding: content/downloads/Loan Review Department Managers Forum/ (stored 0%)
#   adding: content/downloads/Loan Review Department Managers Forum/1.insurance-risk-management-forum.jpg (deflated 16%)
#   adding: content/downloads/AFRDS Conference & Expo/ (stored 0%)
#   adding: content/downloads/AFRDS Conference & Expo/1.afrds_homepage_STD.jpg (deflated 0%)
#   adding: content/downloads/NACS Show/ (stored 0%)
#   adding: content/downloads/NACS Show/1.0-nacsshowfloor-2017_0.jpg (deflated 1%)
#   adding: content/downloads/Cabo Wabo Cantina/ (stored 0%)
#   adding: content/downloads/Cabo Wabo Cantina/1.vegas-rockout.jpg (deflated 0%)
#   adding: content/downloads/Navratri/ (stored 0%)
#   adding: content/downloads/Navratri/1.happy-chaitra-navratri.jpg (deflated 0%)
#   adding: content/downloads/Count's Vamp'd/ (stored 0%)
#   adding: content/downloads/Count's Vamp'd/1.count-vamp-d-bar-grill.jpg (deflated 0%)
#   adding: content/downloads/Orthodox Easter Monday/ (stored 0%)
#   adding: content/downloads/Orthodox Easter Monday/1.orthodox-easter-monday-canada.jpg (deflated 0%)
#   adding: content/downloads/Henderson Executive Airport/ (stored 0%)
#   adding: content/downloads/MGM Grand--Las Vegas/ (stored 0%)
#   adding: content/downloads/MGM Grand--Las Vegas/1.mgm-grand-las-vegasb.jpg (deflated 2%)
#   adding: content/downloads/National Provider Enrollment Forum/ (stored 0%)
#   adding: content/downloads/National Provider Enrollment Forum/1.2dc95b0b5505aaf0fe38ee6d247e546e98ae4dca7a3d3274e44905da56d135e8-rimg-w526-h275-gmir.jpg (deflated 1%)
#   adding: content/downloads/Art Of Music Gallery/ (stored 0%)
#   adding: content/downloads/Art Of Music Gallery/1.15music1-articleLarge.jpg (deflated 1%)
#   adding: content/downloads/Red Rock Casino Resort & Spa/ (stored 0%)
#   adding: content/downloads/Red Rock Casino Resort & Spa/1.RR_Welcome_3.jpg (deflated 0%)
#   adding: content/downloads/ITAR Defense Trade Controls/ (stored 0%)
#   adding: content/downloads/ITAR Defense Trade Controls/1.bigstock-Lincoln-Memorial-130330-540x405.jpg (deflated 10%)
#   adding: content/downloads/XS Las Vegas/ (stored 0%)
#   adding: content/downloads/XS Las Vegas/1.xs-nightclub-by-Danny-Mahoney-2019-billboard-1548.jpg (deflated 0%)
#   adding: content/downloads/Whitney Peak Hotel/ (stored 0%)
#   adding: content/downloads/The Venetian - The Palazzo/ (stored 0%)
#   adding: content/downloads/The Venetian - The Palazzo/1.venetian-exterior_900x600.jpg (stored 0%)
#   adding: content/downloads/Town Square Park/ (stored 0%)
#   adding: content/downloads/Town Square Park/1.tslvpark.jpg (deflated 1%)
#   adding: content/downloads/World Wildlife Day/ (stored 0%)
#   adding: content/downloads/World Wildlife Day/1.WWD2019_2_0.jpg (deflated 1%)
#   adding: content/downloads/Indoor Ag-Con/ (stored 0%)
#   adding: content/downloads/Jimmy Kimmel's Comedy Club/ (stored 0%)
#   adding: content/downloads/Jimmy Kimmel's Comedy Club/1.1570468439976.jpg (deflated 0%)
#   adding: content/downloads/Women's Expo/ (stored 0%)
#   adding: content/downloads/Women's Expo/1.1341984_orig.jpg (deflated 0%)
#   adding: content/downloads/Janmashtami/ (stored 0%)
#   adding: content/downloads/Janmashtami/1.krishna-janmashtami_3.jpg (deflated 1%)
#   adding: content/downloads/Aston MonteLago Village Resort/ (stored 0%)
#   adding: content/downloads/Aston MonteLago Village Resort/1.original.jpg (deflated 0%)
#   adding: content/downloads/High Roller/ (stored 0%)
#   adding: content/downloads/High Roller/1.high-roller.jpg (deflated 1%)
#   adding: content/downloads/World Population Day/ (stored 0%)
#   adding: content/downloads/World Population Day/1.world-population-day-647_071117062346.jpg (deflated 1%)
#   adding: content/downloads/DEF CON/ (stored 0%)
#   adding: content/downloads/Baskin-Robbins/ (stored 0%)
#   adding: content/downloads/Baskin-Robbins/1.mint-chocolate-chip-ice.jpg (deflated 0%)
#   adding: content/downloads/Henderson Pet Expo/ (stored 0%)
#   adding: content/downloads/Henderson Pet Expo/1.PamperYourPet2019cover.jpg (deflated 1%)
#   adding: content/downloads/Pubcon Las Vegas/ (stored 0%)
#   adding: content/downloads/Pubcon Las Vegas/1.pubcon-hero.jpg (deflated 1%)
#   adding: content/downloads/Jubilee Theater at Ballys Las Vegas/ (stored 0%)
#   adding: content/downloads/Jubilee Theater at Ballys Las Vegas/1.6d53248561d48630e46eac567f1a10b1.jpg (deflated 0%)
#   adding: content/downloads/The Cosmopolitan of Las Vegas - Boulevard Pool/ (stored 0%)
#   adding: content/downloads/The Cosmopolitan of Las Vegas - Boulevard Pool/1.20160915_cosmo-boulevard_wide.jpg (deflated 1%)
#   adding: content/downloads/Tempo Afterhours/ (stored 0%)
#   adding: content/downloads/Sport Center of Las Vegas/ (stored 0%)
#   adding: content/downloads/Sport Center of Las Vegas/1.AEC-Sportcenter-Las-Vegas-3.jpg (deflated 4%)
#   adding: content/downloads/The Venetian - The Palazzo Ballroom/ (stored 0%)
#   adding: content/downloads/The Venetian - The Palazzo Ballroom/1.2492579697_f5bbd8a3c1_z.jpg (deflated 1%)
#   adding: content/downloads/Corpus Christi/ (stored 0%)
#   adding: content/downloads/Corpus Christi/1.corpus-christi-skyline-header.jpg (deflated 1%)
#   adding: content/downloads/World Day of Remembrance for Road Traffic Victims/ (stored 0%)
#   adding: content/downloads/World Day of Remembrance for Road Traffic Victims/1.wdor-logo-for-slider_update-R.jpg (deflated 3%)
#   adding: content/downloads/National Tartan Day/ (stored 0%)
#   adding: content/downloads/National Tartan Day/1.tartan-day-canada.jpg (deflated 0%)
#   adding: content/downloads/International Day for the Elimination of Violence against Women/ (stored 0%)
#   adding: content/downloads/International Day for the Elimination of Violence against Women/1.International-Day-for-the-Elimination-of-Violence-Against-Women-November-25-1.jpg (deflated 4%)
#   adding: content/downloads/The Golden Tiki/ (stored 0%)
#   adding: content/downloads/The Golden Tiki/1.9063163_web1_tiki-aug23-17-bh-0049.jpg (deflated 0%)
#   adding: content/downloads/Family Music Center Theater/ (stored 0%)
#   adding: content/downloads/MSPExpo/ (stored 0%)
#   adding: content/downloads/Terrace Afterhours/ (stored 0%)
#   adding: content/downloads/Terrace Afterhours/1.1522532882-25129481-850x500-Hustler-Club-Terrace.jpg (deflated 0%)
#   adding: content/downloads/Las Vegas RoadShow/ (stored 0%)
#   adding: content/downloads/Las Vegas RoadShow/1.roadshow-lv-hero-01.jpg (deflated 0%)
#   adding: content/downloads/Las Vegas Country Saloon/ (stored 0%)
#   adding: content/downloads/Las Vegas Country Saloon/1.Gilleys_MechanicalBull.jpg (deflated 3%)
#   adding: content/downloads/6655 Sahara Ave/ (stored 0%)
#   adding: content/downloads/Embassy Suites by Hilton Convention Center Las Vegas/ (stored 0%)
#   adding: content/downloads/Embassy Suites by Hilton Convention Center Las Vegas/1.ES_exteriornight01_712x342_FitToBoxSmallDimension_Center.jpg (deflated 1%)
#   adding: content/downloads/Funderdome! Improv Comedy Battle/ (stored 0%)
#   adding: content/downloads/Funderdome! Improv Comedy Battle/1.bnmbjorwesbbfmbxqjwb.jpg (deflated 1%)
#   adding: content/downloads/West Las Vegas Library/ (stored 0%)
#   adding: content/downloads/West Las Vegas Library/1.original_4053_West_Las_Vegas_Library.jpg (deflated 1%)
#   adding: content/downloads/SUN CITY ALIANTE VISTA CABARET/ (stored 0%)
#   adding: content/downloads/SUN CITY ALIANTE VISTA CABARET/1.adult-pool-v17146639-1440-1024x683.jpg (deflated 0%)
#   adding: content/downloads/Rise Festival/ (stored 0%)
#   adding: content/downloads/Rise Festival/1.12793151_web1_webRISE-FEST-OCT06-18-BH-016.jpg (deflated 0%)
#   adding: content/downloads/International Watch & Jewelry Guild Show/ (stored 0%)
#   adding: content/downloads/International Watch & Jewelry Guild Show/1.11164666_10152818053612218_5892775617425828666_n-700x469.jpg (deflated 0%)
#   adding: content/downloads/Pole Fitness Studio/ (stored 0%)
#   adding: content/downloads/Red Rock Canyon National Conservation Area/ (stored 0%)
#   adding: content/downloads/Red Rock Canyon National Conservation Area/1.original-redrocklandscape-0.jpg (deflated 0%)
#   adding: content/downloads/Harrah's Showroom/ (stored 0%)
#   adding: content/downloads/Harrah's Showroom/1.sammy-s-showroom.jpg (deflated 0%)
#   adding: content/downloads/M Resort Spa Casino/ (stored 0%)
#   adding: content/downloads/M Resort Spa Casino/1.26199370.jpg (deflated 0%)
#   adding: content/downloads/Texas Station/ (stored 0%)
#   adding: content/downloads/Texas Station/1.TS_Hotel_Exterior1-newlowrez.jpg (deflated 1%)
#   adding: content/downloads/Harvest Festival Original Art & Craft Show-Las Vegas/ (stored 0%)
#   adding: content/downloads/World Vegetarian Day/ (stored 0%)
#   adding: content/downloads/World Vegetarian Day/1.world-vegetarian-day-640x514.jpg (deflated 0%)
#   adding: content/downloads/St. David's Day/ (stored 0%)
#   adding: content/downloads/St. David's Day/1.St-David-s-Day-2019-messages-and-greetings-1094029.jpg (deflated 0%)
#   adding: content/downloads/Boulder Station Hotel & Casino/ (stored 0%)
#   adding: content/downloads/World Elder Abuse Awareness Day/ (stored 0%)
#   adding: content/downloads/Donny and Marie Showroom/ (stored 0%)
#   adding: content/downloads/Donny and Marie Showroom/1.view-from-balcony.jpg (deflated 0%)
#   adding: content/downloads/Human Rights Day/ (stored 0%)
#   adding: content/downloads/Human Rights Day/1.WHRD.jpg (deflated 2%)
#   adding: content/downloads/Paris Las Vegas Pool/ (stored 0%)
#   adding: content/downloads/Paris Las Vegas Pool/1.1574791203742.jpg (deflated 0%)
#   adding: content/downloads/Four Points by Sheraton Las Vegas East Flamingo/ (stored 0%)
#   adding: content/downloads/Four Points by Sheraton Las Vegas East Flamingo/1.lasff-exterior-8109-hor-feat.jpg (deflated 0%)
#   adding: content/downloads/Center for Science & Wonder/ (stored 0%)
#   adding: content/downloads/International Mother Language Day/ (stored 0%)
#   adding: content/downloads/International Mother Language Day/1.mother-language-day.jpg (deflated 1%)
#   adding: content/downloads/Canyon Ridge Christian Church/ (stored 0%)
#   adding: content/downloads/FBC Mortgage/ (stored 0%)
#   adding: content/downloads/FBC Mortgage/1.dsc8317*750xx3696-2089-0-352.jpg (deflated 0%)
#   adding: content/downloads/Stones Spot/ (stored 0%)
#   adding: content/downloads/Stones Spot/1.684b9c8e86f0886a210bd031b19e6e02.jpg (deflated 0%)
#   adding: content/downloads/The Blue Man Theatre/ (stored 0%)
#   adding: content/downloads/The Blue Man Theatre/1.Blue-Man-Group_Luxor-01.jpg (deflated 4%)
#   adding: content/downloads/Army Birthday/ (stored 0%)
#   adding: content/downloads/Army Birthday/1.Army-Birthday-Landing-Page-header-2019.jpg (deflated 4%)
#   adding: content/downloads/World Meteorological Day/ (stored 0%)
#   adding: content/downloads/World Meteorological Day/1.WMD2017_poster_branding_nolink_JN1791_EN.jpg (deflated 1%)
#   adding: content/downloads/Rehab Beach Club/ (stored 0%)
#   adding: content/downloads/Rehab Beach Club/1.best-venue-for-a-beach.jpg (deflated 0%)
#   adding: content/downloads/Isra and Mi'raj/ (stored 0%)
#   adding: content/downloads/Isra and Mi'raj/1.isra-miraj-canada.jpg (deflated 0%)
#   adding: content/downloads/Tuscany Suites & Casino Florentine Ballroom and Tuscany Event Center – 2nd Floor/ (stored 0%)
#   adding: content/downloads/Tuscany Suites & Casino Florentine Ballroom and Tuscany Event Center – 2nd Floor/1.arbisoftimages-31427-proofs-163-image.jpg (deflated 0%)
#   adding: content/downloads/SIA Global Executive Summit/ (stored 0%)
#   adding: content/downloads/SIA Global Executive Summit/1.Attendify-Summit-Pic.jpg (deflated 1%)
#   adding: content/downloads/MEET Las Vegas/ (stored 0%)
#   adding: content/downloads/MEET Las Vegas/1.18-MEETLV-Popup.jpg (deflated 2%)
#   adding: content/downloads/Father's Day/ (stored 0%)
#   adding: content/downloads/Father's Day/1.1280x960_30614C00-ZYSBP.jpg (deflated 3%)
#   adding: content/downloads/Iconic/ (stored 0%)
#   adding: content/downloads/Iconic/1.IL_PrepSet_Original_120ml_0b1653af-d893-4c4b-a7fa-3d4db9d935c2_534x500_crop_bottom.jpg (deflated 17%)
#   adding: content/downloads/Congregation Ner Tamid/ (stored 0%)
#   adding: content/downloads/Congregation Ner Tamid/1.520a1d_4168e82420ad4184815c1c915d797f2e~mv2.jpg (deflated 1%)
#   adding: content/downloads/Paris Hotel & Casino/ (stored 0%)
#   adding: content/downloads/International Day to End Impunity for Crimes against Journalists/ (stored 0%)
#   adding: content/downloads/International Day to End Impunity for Crimes against Journalists/1.poster.jpg (deflated 3%)
#   adding: content/downloads/Africa Industrialization Day/ (stored 0%)
#   adding: content/downloads/The Cabaret at Planet Hollywood Las Vegas/ (stored 0%)
#   adding: content/downloads/The Cabaret at Planet Hollywood Las Vegas/1.CiMx4RCXAAA_Mws.jpg (deflated 1%)
#   adding: content/downloads/Hookah Expo Worldwide/ (stored 0%)
#   adding: content/downloads/Hookah Expo Worldwide/1.2019-0291-0008.jpg (deflated 2%)
#   adding: content/downloads/Law Day/ (stored 0%)
#   adding: content/downloads/Law Day/1.law-day.jpg (deflated 2%)
#   adding: content/downloads/Las Vegas Marriott/ (stored 0%)
#   adding: content/downloads/Las Vegas Marriott/1.lasst-exterior-0049-hor-feat.jpg (deflated 1%)
#   adding: content/downloads/ABC Kids Expo/ (stored 0%)
#   adding: content/downloads/ABC Kids Expo/1.abcexpo-1.jpg (deflated 0%)
#   adding: content/downloads/Sam's Town Hotel & Gambling Hall/ (stored 0%)
#   adding: content/downloads/Sam's Town Hotel & Gambling Hall/1.8f43eaa11d55b3e5705304a34c646647.jpg (deflated 1%)
#   adding: content/downloads/Tropicana Las Vegas  Cohiba Ballroom/ (stored 0%)
#   adding: content/downloads/Tropicana Las Vegas  Cohiba Ballroom/1.bulletedlist-image-churchhillmeeting-486x273.jpg (deflated 2%)
#   adding: content/downloads/International Day for the Preservation of the Ozone Layer/ (stored 0%)
#   adding: content/downloads/International Day for the Preservation of the Ozone Layer/1.International-Day-For-The-Preservation-Of-The-Ozone-Layer-Image.jpg (deflated 1%)
#   adding: content/downloads/Valley Bible Fellowship/ (stored 0%)
#   adding: content/downloads/Valley Bible Fellowship/1.15-100_Valley-Bible-Fellowship.jpg (deflated 1%)
#   adding: content/downloads/THE JAM Open Mic Night @ Ninja Karaoke/ (stored 0%)
#   adding: content/downloads/THE JAM Open Mic Night @ Ninja Karaoke/1.https%3A%2F%2Fcdn.evbuc.com%2Fimages%2F69622167%2F282049950275%2F1%2Foriginal.jpg (deflated 1%)
#   adding: content/downloads/Fresha Wata HQ/ (stored 0%)
#   adding: content/downloads/Fresha Wata HQ/1.IG-1.jpg (deflated 0%)
#   adding: content/downloads/National Vietnam War Veterans Day/ (stored 0%)
#   adding: content/downloads/National Vietnam War Veterans Day/1.CC-19144-Header-Vietnam-War-Veterans-Day-2019.jpg (deflated 1%)
#   adding: content/downloads/International Day for the Abolition of Slavery/ (stored 0%)
#   adding: content/downloads/International Day for the Abolition of Slavery/1.abolitionslavery.jpg (deflated 3%)
#   adding: content/downloads/Troesh Studio Theater at The Smith Center/ (stored 0%)
#   adding: content/downloads/Troesh Studio Theater at The Smith Center/1.the-smith-center-s-troesh.jpg (deflated 0%)
#   adding: content/downloads/Hampton Inn & Suites Las Vegas Airport/ (stored 0%)
#   adding: content/downloads/Hampton Inn & Suites Las Vegas Airport/1.172709100.jpg (deflated 1%)
#   adding: content/downloads/World Habitat Day/ (stored 0%)
#   adding: content/downloads/World Habitat Day/1.world-habitat-day_31012.jpg (deflated 10%)
#   adding: content/downloads/International SITE Conference/ (stored 0%)
#   adding: content/downloads/International SITE Conference/1.Insights%2FPara%20Site%2FDiary%201%2FDSF2073_720_0.jpg (deflated 4%)
#   adding: content/downloads/Green Valley Library/ (stored 0%)
#   adding: content/downloads/Green Valley Library/1.green-valley-branch-page.jpg (deflated 0%)
#   adding: content/downloads/National POW/ (stored 0%)
#   adding: content/downloads/National POW/MIA Recognition Day/ (stored 0%)
#   adding: content/downloads/National POW/MIA Recognition Day/1.pow-mia-day.jpg (deflated 1%)
#   adding: content/downloads/Sahara Theater/ (stored 0%)
#   adding: content/downloads/Sahara Theater/1.l.jpg (deflated 0%)
#   adding: content/downloads/Source Direct at ASD/ (stored 0%)
#   adding: content/downloads/Bastille Day/ (stored 0%)
#   adding: content/downloads/Bastille Day/1.aifs-study-abroad-paris-france-bastille-day.jpg (deflated 2%)
#   adding: content/downloads/AMC Rainbow Promenade 10/ (stored 0%)
#   adding: content/downloads/AMC Rainbow Promenade 10/1.04190_rainbowpromenade_mobile.jpg (deflated 1%)
#   adding: content/downloads/eLearning Conference/ (stored 0%)
#   adding: content/downloads/eLearning Conference/1.3374rp.jpg (deflated 1%)
#   adding: content/downloads/Lag BaOmer/ (stored 0%)
#   adding: content/downloads/Air Force Birthday/ (stored 0%)
#   adding: content/downloads/Air Force Birthday/1.air-force-birthday-2019-lp-header.jpg (deflated 1%)
#   adding: content/downloads/Bill of Rights Day/ (stored 0%)
#   adding: content/downloads/Bill of Rights Day/1.5a33353d1600002800cf151f.jpg (deflated 0%)
#   adding: content/downloads/3930 Cambridge St/ (stored 0%)
#   adding: content/downloads/Chinese Language Day/ (stored 0%)
#   adding: content/downloads/Chinese Language Day/1.chinese-language-day1-896x600.jpg (deflated 0%)
#   adding: content/downloads/Holi/ (stored 0%)
#   adding: content/downloads/Holi/1.holi-in-singapore.jpg (deflated 18%)
#   adding: content/downloads/Self-Injury Awareness Day/ (stored 0%)
#   adding: content/downloads/Self-Injury Awareness Day/1.Self-Injry-Awareness-Day-March-1-1024x512.jpg (deflated 1%)
#   adding: content/downloads/Hakkasan Las Vegas Nightclub/ (stored 0%)
#   adding: content/downloads/Hakkasan Las Vegas Nightclub/1.hakkasan3.jpg (deflated 0%)
#   adding: content/downloads/Stratosphere Hotel and Casino - The Dragon Room/ (stored 0%)
#   adding: content/downloads/Stratosphere Hotel and Casino - The Dragon Room/1.stratosphere-nightlife-las-vegas.jpg (deflated 0%)
#   adding: content/downloads/Jokesters Comedy Club/ (stored 0%)
#   adding: content/downloads/Jokesters Comedy Club/1.jokesters-comedy-club.jpg (deflated 0%)
#   adding: content/downloads/Constitution Day and Citizenship Day/ (stored 0%)
#   adding: content/downloads/Constitution Day and Citizenship Day/1.Constitution-Day-and-Citizenship-Day-September-17-1.jpg (deflated 0%)
#   adding: content/downloads/College of Southern Nevada - Charleston Campus/ (stored 0%)
#   adding: content/downloads/College of Southern Nevada - Charleston Campus/1.web1_csn-charleston-campus_011910_6.jpg (deflated 0%)
#   adding: content/downloads/The Light Vegas/ (stored 0%)
#   adding: content/downloads/The Light Vegas/1.rockbear-for-light-63-1024x683.jpg (deflated 0%)
#   adding: content/downloads/Psychiatry Update Encore Presentation/ (stored 0%)
#   adding: content/downloads/Psychiatry Update Encore Presentation/1.aacp_2018.jpg (deflated 1%)
#   adding: content/downloads/Independence Day/ (stored 0%)
#   adding: content/downloads/Independence Day/1.topic-july-4-gettyimages-815196336.jpg (deflated 1%)
#   adding: content/downloads/Whit Monday/ (stored 0%)
#   adding: content/downloads/Marquee Las Vegas/ (stored 0%)
#   adding: content/downloads/Marquee Las Vegas/1.3604905.jpg (deflated 0%)
#   adding: content/downloads/Sands Showroom at the Venetian/ (stored 0%)
#   adding: content/downloads/Sands Showroom at the Venetian/1.the-sands-showroom-a.jpg (deflated 0%)
#   adding: content/downloads/Gordon Biersch Brewery Restaurant/ (stored 0%)
#   adding: content/downloads/Gordon Biersch Brewery Restaurant/1.4305_197_1613af0b-5056-b365-ab5012d775c7362d.jpg (deflated 0%)
#   adding: content/downloads/Panevino Lounge/ (stored 0%)
#   adding: content/downloads/Panevino Lounge/1.p-Panevino-Wide-1A_54_990x660_201406020244.jpg (deflated 0%)
#   adding: content/downloads/Aerial Fitness/ (stored 0%)
# ...
#   adding: content/downloads/Fremont Street Experience/ (stored 0%)
#   adding: content/downloads/DigiWorld Entertainment/ (stored 0%)
#   adding: content/downloads/DigiWorld Entertainment/1.8237929_web1_no-digiworldent-apr13-17_032917cl_004.jpg (deflated 1%)
#   adding: content/downloads/UNLV - International Gaming Institute/ (stored 0%)
#   adding: content/downloads/UNLV - International Gaming Institute/1.SFB-D67840_27.jpg (deflated 0%)
#   adding: content/downloads/World Humanitarian Day/ (stored 0%)
#   adding: content/downloads/World Humanitarian Day/1.story_wide-1439498101.jpg (deflated 1%)
#   adding: content/downloads/Fashion Show Mall/ (stored 0%)
#   adding: content/downloads/Fashion Show Mall/1.web1_bp-reconreview-may11-15_018_6.jpg (deflated 0%)
#   adding: content/downloads/The Venue Las Vegas/ (stored 0%)
#   adding: content/downloads/ERA Real Estate Conference/ (stored 0%)
#   adding: content/downloads/ERA Real Estate Conference/1.ERA_portfolio_launch.jpg (deflated 2%)
#   adding: content/downloads/Rolling in the Dough/ (stored 0%)
#   adding: content/downloads/Rolling in the Dough/1.funny-cat-bathtub-money.jpg (deflated 3%)
#   adding: content/downloads/Century Orleans 18 Movie Theater/ (stored 0%)
#   adding: content/downloads/Century Orleans 18 Movie Theater/1.TO_entertain_movie_theater_KeyFeatures_640x356.jpg (deflated 15%)
#   adding: content/downloads/Chron's and Colitis Congress/ (stored 0%)
#   adding: content/downloads/Chron's and Colitis Congress/1.886x590x4-886x590.jpg (deflated 0%)
#   adding: content/downloads/Chinese New Year/ (stored 0%)
#   adding: content/downloads/Chinese New Year/1.chinese-new-year-lanterns.jpg (deflated 2%)
#   adding: content/downloads/Artisan Craft Festival/ (stored 0%)
#   adding: content/downloads/Artisan Craft Festival/1.img1.jpg (deflated 19%)
#   adding: content/downloads/Flag Day/ (stored 0%)
#   adding: content/downloads/Flag Day/1.Flag-Day-2019-LP-Header_0.jpg (deflated 0%)
#   adding: content/downloads/Oasis at Gold Spike/ (stored 0%)
#   adding: content/downloads/Oasis at Gold Spike/1.6865b7d5_z.jpg (deflated 0%)
#   adding: content/downloads/Fremont Country Club/ (stored 0%)
#   adding: content/downloads/Fremont Country Club/1.Fremont-Country-Club-Las-Vegas.jpg (deflated 2%)
#   adding: content/downloads/Harrah's Cabaret at Harrah's Las Vegas/ (stored 0%)
#   adding: content/downloads/Harrah's Cabaret at Harrah's Las Vegas/1.1547770318945.jpg (deflated 1%)
#   adding: content/downloads/Innovative School Summit/ (stored 0%)
#   adding: content/downloads/Orthodox Easter/ (stored 0%)
#   adding: content/downloads/Orthodox Easter/1.easter-monday-orthodox.jpg (deflated 0%)
#   adding: content/downloads/Self Storage Association Conference & Trade Show/ (stored 0%)
#   adding: content/downloads/Self Storage Association Conference & Trade Show/1.resizeFSSA%20GOBO.jpg (deflated 9%)
#   adding: content/downloads/Miller Lite Conciertos Originales - Las Vegas  NV/ (stored 0%)
#   adding: content/downloads/Miller Lite Conciertos Originales - Las Vegas  NV/1.https%3A%2F%2Fcdn.evbuc.com%2Fimages%2F44472827%2F177045668748%2F1%2Foriginal.jpg (deflated 2%)
#   adding: content/downloads/IRE/ (stored 0%)
#   adding: content/downloads/IRE/1.a2310028313_5.jpg (deflated 13%)
#   adding: content/downloads/Guitar Center/ (stored 0%)
#   adding: content/downloads/Clark County Government Center Amphitheater/ (stored 0%)
#   adding: content/downloads/Clark County Government Center Amphitheater/1.amphitheater-4.jpg (deflated 1%)
#   adding: content/downloads/La Jolla/ (stored 0%)
#   adding: content/downloads/La Jolla/1.CN_Blog_AskALocal_SanDiego_ST_RM_LaJollaCove_632168041.jpg (deflated 28%)
#   adding: content/downloads/World Day against Trafficking in Persons/ (stored 0%)
#   adding: content/downloads/World Day against Trafficking in Persons/1.featured-image-index-sm.jpg (deflated 4%)
#   adding: content/downloads/Hooters Hotel - Night Owl Showroom/ (stored 0%)
#   adding: content/downloads/Hooters Hotel - Night Owl Showroom/1.night-owl-showroom-hooters.jpg (deflated 0%)
#   adding: content/downloads/Second City Tours - Clark & Superior/ (stored 0%)
#   adding: content/downloads/Second City Tours - Clark & Superior/1.genMid.10577970_0.jpg (deflated 0%)
#   adding: content/downloads/Arizona Charlie's Decatur/ (stored 0%)
#   adding: content/downloads/Arizona Charlie's Decatur/1.homeimg.jpg (deflated 3%)
#   adding: content/downloads/International Civil Aviation Day/ (stored 0%)
#   adding: content/downloads/International Civil Aviation Day/1.International-Civil-Aviation-Organisation-ICAO.jpg (deflated 6%)
#   adding: content/downloads/Rio All-Suites Hotel and Casino - Comedy Cellar/ (stored 0%)
#   adding: content/downloads/Rio All-Suites Hotel and Casino - Comedy Cellar/1.1524869560731.jpg (deflated 0%)
#   adding: content/downloads/March Equinox/ (stored 0%)
#   adding: content/downloads/March Equinox/1.me1.jpg (deflated 2%)
#   adding: content/downloads/New York-New York Hotel & Casino/ (stored 0%)
#   adding: content/downloads/New York-New York Hotel & Casino/1.193378654.jpg (deflated 2%)
#   adding: content/downloads/The Parlor Cocktail Lounge/ (stored 0%)
#   adding: content/downloads/The Parlor Cocktail Lounge/1.mirage_center_bar1.jpg (deflated 0%)
#   adding: content/downloads/University Of Las Vegas/ (stored 0%)
#   adding: content/downloads/University Of Las Vegas/1.pioneering_spirit-D71340_026-480x320.jpg (deflated 0%)
#   adding: content/downloads/World Kidney Day/ (stored 0%)
#   adding: content/downloads/World Kidney Day/1.kidney_650x400_41520514908.jpg (deflated 7%)
#   adding: content/downloads/The Bank/ (stored 0%)
#   adding: content/downloads/The Bank/1.photo1jpg.jpg (deflated 0%)
#   adding: content/downloads/Canyon Club/ (stored 0%)
#   adding: content/downloads/Canyon Club/1.the-canyon-club.jpg (deflated 1%)
#   adding: content/downloads/Holy Saturday/ (stored 0%)
#   adding: content/downloads/Holy Saturday/1.Akin-REINCARNATION1.jpg (deflated 2%)
#   adding: content/downloads/The Platinum Hotel & Spa/ (stored 0%)
#   adding: content/downloads/The Platinum Hotel & Spa/1.191407677.jpg (deflated 1%)
#   adding: content/downloads/Erotic Heritage Museum/ (stored 0%)
#   adding: content/downloads/Erotic Heritage Museum/1.erotic-heritage-museum.jpg (deflated 0%)
#   adding: content/downloads/House of Tape at Harrah's Las Vegas/ (stored 0%)
#   adding: content/downloads/House of Tape at Harrah's Las Vegas/1.10262030_web1_tape-taping.jpg (deflated 0%)
#   adding: content/downloads/Regal Cinemas Sunset Station 13 & IMAX/ (stored 0%)
#   adding: content/downloads/Regal Cinemas Sunset Station 13 & IMAX/1.-visit_to_Regal_Cinemas_Su-20000000009403931-500x375.jpg (deflated 0%)
#   adding: content/downloads/WEICHERT  REALTORS® - Millennium/ (stored 0%)
#   adding: content/downloads/WEICHERT  REALTORS® - Millennium/1.hqdefault.jpg (deflated 5%)
#   adding: content/downloads/South Point Showroom at South Point Hotel Casino and Spa/ (stored 0%)
#   adding: content/downloads/South Point Showroom at South Point Hotel Casino and Spa/1.showroom.jpg (deflated 0%)
#   adding: content/downloads/Curago Vita Wellness Institute/ (stored 0%)
#   adding: content/downloads/Curago Vita Wellness Institute/1.curacao-pc-eduardo-gato-playa-porto-mari-sign.jpg (deflated 0%)
#   adding: content/downloads/CLUB HIS HOP/ (stored 0%)
#   adding: content/downloads/CLUB HIS HOP/1.14054498_10205419769532430_412955637151869462_o.jpg (deflated 1%)
#   adding: content/downloads/Summerlin Library/ (stored 0%)
#   adding: content/downloads/Summerlin Library/1.original_4041_Summerlin_Library.jpg (deflated 0%)
#   adding: content/downloads/BUSINESS EXPO & CAREER FAIR 2018/ (stored 0%)
#   adding: content/downloads/BUSINESS EXPO & CAREER FAIR 2018/1.photo-from-career-fair-and-business-expo-217___19131956196.jpg (deflated 1%)
#   adding: content/downloads/Suncoast Hotel and Casino/ (stored 0%)
#   adding: content/downloads/Suncoast Hotel and Casino/1.15042225.jpg (deflated 1%)
#   adding: content/downloads/Itsy Bitsy/ (stored 0%)
#   adding: content/downloads/Itsy Bitsy/1.9781486715657_p0_v1_s550x406.jpg (deflated 0%)
#   adding: content/downloads/HDexpo/ (stored 0%)
#   adding: content/downloads/HDexpo/1.hd-expo.jpg (deflated 4%)
#   adding: content/downloads/Lvl Up Expo/ (stored 0%)
#   adding: content/downloads/Lvl Up Expo/1.sitemgr_photo_3328.jpg (deflated 3%)
#   adding: content/downloads/Aria Resort & Casino/ (stored 0%)
#   adding: content/downloads/Aria Resort & Casino/1.aria-hotel-exterior-with-lumia-updated.jpg (deflated 1%)
#   adding: content/downloads/Valley Bible Fellowship Of Las Vegas Church/ (stored 0%)
#   adding: content/downloads/Valley Bible Fellowship Of Las Vegas Church/1.16ideas-Reaching-Sin-City-Valley-Bible-Fellowship-in-Las-Vegas-1019.jpg (deflated 1%)
#   adding: content/downloads/Cannery Casino & Hotel/ (stored 0%)
#   adding: content/downloads/Cannery Casino & Hotel/1.73471913.jpg (deflated 0%)
#   adding: content/downloads/Pinot's Palette/ (stored 0%)
#   adding: content/downloads/Pinot's Palette/1.PinotsPaletteNightOut0-bc42e82c5056b36_bc42eca2-5056-b365-ab389af923e8fc16.jpg (deflated 0%)
#   adding: content/downloads/International Day of Commemoration in Memory of the Victims of the Holocaust/ (stored 0%)
#   adding: content/downloads/St. Patrick's Day/ (stored 0%)
#   adding: content/downloads/St. Patrick's Day/1.st-patricks-day-global2.jpg (deflated 0%)
#   adding: content/downloads/Assumption of Mary/ (stored 0%)
#   adding: content/downloads/Assumption of Mary/1.Assumption_Of_Mary640.jpg (deflated 0%)
#   adding: content/downloads/Brand Innovators Mega Trends/ (stored 0%)
#   adding: content/downloads/Brand Innovators Mega Trends/1.riseofvisualweb-final-150930004410-lva1-app6891-thumbnail-4.jpg (deflated 0%)
#   adding: content/downloads/Canyon Gate Country Club/ (stored 0%)
#   adding: content/downloads/Canyon Gate Country Club/1.Canyon-Gate_Golf_Gal1_largeimage.jpg (deflated 2%)
#   adding: content/downloads/NUDE POOL LAS VEGAS  the ultimate couples Pool Parties 24 hours couples and women only and 24 hour dance club/ (stored 0%)
#   adding: content/downloads/NUDE POOL LAS VEGAS  the ultimate couples Pool Parties 24 hours couples and women only and 24 hour dance club/1.seamountaindhs1017-248-640.jpg (deflated 0%)
#   adding: content/downloads/Kwanzaa (first day)/ (stored 0%)
#   adding: content/downloads/Kwanzaa (first day)/1.edea76f22bba73f5008e9bb963ab5f42.jpg (deflated 1%)
#   adding: content/downloads/Circus Circus Act/ (stored 0%)
#   adding: content/downloads/Circus Circus Act/1.hoop-act.jpg (deflated 0%)
#   adding: content/downloads/International Day of Forests/ (stored 0%)
#   adding: content/downloads/International Day for the Elimination of Sexual Violence in Conflict/ (stored 0%)
#   adding: content/downloads/International Day for the Elimination of Sexual Violence in Conflict/1.featured-image-index-sm.jpg (deflated 0%)
#   adding: content/downloads/International Day for Natural Disaster Reduction/ (stored 0%)
#   adding: content/downloads/International Day for Natural Disaster Reduction/1.blog-post-pic1.jpg (deflated 0%)
#   adding: content/downloads/East Las Vegas Community/ (stored 0%)
#   adding: content/downloads/East Las Vegas Community/Senior Center/ (stored 0%)
#   adding: content/downloads/East Las Vegas Community/Senior Center/1.348s.jpg (deflated 1%)
#   adding: content/downloads/The Windmill Performing Arts Center/ (stored 0%)
#   adding: content/downloads/The Windmill Performing Arts Center/1.IMG_0100.JPG (deflated 0%)
#   adding: content/downloads/Rio Showroom at Rio Las Vegas/ (stored 0%)
#   adding: content/downloads/Rio Showroom at Rio Las Vegas/1.efb3740de93b8569ba6040bb5764672c.jpg (deflated 0%)
#   adding: content/downloads/Rosh Hashana/ (stored 0%)
#   adding: content/downloads/Rosh Hashana/1.FvBD9811721.jpg (deflated 4%)
#   adding: content/downloads/Aliante Golf Club/ (stored 0%)
#   adding: content/downloads/Aliante Golf Club/1.HPIM0827.JPG (deflated 0%)
#   adding: content/downloads/April Fool's Day/ (stored 0%)
#   adding: content/downloads/April Fool's Day/1.april-fools-fish.jpg (deflated 0%)
#   adding: content/downloads/Workforce Connections - One Stop Career Center/ (stored 0%)
#   adding: content/downloads/Workforce Connections - One Stop Career Center/1.web1_careercenter_7906500.jpg (deflated 1%)
#   adding: content/downloads/SILVERTON CASINO HOTEL/ (stored 0%)
#   adding: content/downloads/SILVERTON CASINO HOTEL/1.3bcaa14c_z.jpg (deflated 0%)
#   adding: content/downloads/Ron DeCars Event Center/ (stored 0%)
#   adding: content/downloads/Ron DeCars Event Center/1.ron-decars-event-center-room-dj.jpg (deflated 0%)
#   adding: content/downloads/Rhythms Event Center/ (stored 0%)
#   adding: content/downloads/Rhythms Event Center/1.2362205_lg.jpg (deflated 0%)
#   adding: content/downloads/Cambridge Recreation Center/ (stored 0%)
#   adding: content/downloads/Cambridge Recreation Center/1.center-aq-cambridge.jpg (deflated 1%)
#   adding: content/downloads/Hard Rock Live/ (stored 0%)
#   adding: content/downloads/Hard Rock Live/1.311_Event_Calendar_Flexslider.jpg (deflated 0%)
#   adding: content/downloads/Sunset Park/ (stored 0%)
#   adding: content/downloads/Sunset Park/1.17812.jpg (deflated 0%)
#   adding: content/downloads/VegeNation/ (stored 0%)
#   adding: content/downloads/VegeNation/1.home-img-1.jpg (deflated 0%)
#   adding: content/downloads/Rainbow Library/ (stored 0%)
#   adding: content/downloads/Rainbow Library/1.62fe7793a03ec23760282beb07d41875.jpg (deflated 0%)
#   adding: content/downloads/International Foot and Ankle Foundation Annual Las Vegas Seminar/ (stored 0%)
#   adding: content/downloads/International Foot and Ankle Foundation Annual Las Vegas Seminar/1.ankle-arthroscopy-course-1.jpg (deflated 1%)
#   adding: content/downloads/NoMad Las Vegas/ (stored 0%)
#   adding: content/downloads/NoMad Las Vegas/1.tmg-article_default_mobile.jpg (deflated 0%)
#   adding: content/downloads/Enclave/ (stored 0%)
#   adding: content/downloads/Bandito Latin Kitchen and Cantina / (stored 0%)
#   adding: content/downloads/Bandito Latin Kitchen and Cantina /1.Bandito_5.jpg (deflated 0%)
#   adding: content/downloads/Courtyard by Marriott Las Vegas Henderson/ (stored 0%)
#   adding: content/downloads/Courtyard by Marriott Las Vegas Henderson/Green Valley/ (stored 0%)
#   adding: content/downloads/Las Vegas Club Hotel & Casino/ (stored 0%)
#   adding: content/downloads/Las Vegas Club Hotel & Casino/1.18_fremont_demolition2.jpg (deflated 0%)
#   adding: content/downloads/Global Shop/ (stored 0%)
#   adding: content/downloads/Las Vegas Motor Speedway - The Bullring/ (stored 0%)
#   adding: content/downloads/Las Vegas Motor Speedway - The Bullring/1.1756213-lg.JPG (deflated 0%)
#   adding: content/downloads/The Mirage- Terry Fator Theatre/ (stored 0%)
#   adding: content/downloads/The Mirage- Terry Fator Theatre/1.631885-1.jpg (deflated 0%)
#   adding: content/downloads/NECHE/ (stored 0%)
#   adding: content/downloads/NECHE/1.Neche%2C_North_Dakota.jpg (deflated 0%)
#   adding: content/downloads/Eagle Aerie Hall/ (stored 0%)
#   adding: content/downloads/Eagle Aerie Hall/1.hqdefault.jpg (deflated 3%)
#   adding: content/downloads/Cosmopolitan of Las Vegas - Marquee Nightclub & Dayclub/ (stored 0%)
#   adding: content/downloads/Cosmopolitan of Las Vegas - Marquee Nightclub & Dayclub/1.marquee-nightclub-lasers.jpg (deflated 0%)
#   adding: content/downloads/First Day of Sukkot/ (stored 0%)
#   adding: content/downloads/First Day of Sukkot/1.sukkot-usa.jpg (deflated 0%)
#   adding: content/downloads/University of Nevada  Las Vegas/ (stored 0%)
#   adding: content/downloads/University of Nevada  Las Vegas/1.greenspun_D69834_01.jpg (deflated 0%)
#   adding: content/downloads/Vanguard Lounge/ (stored 0%)
#   adding: content/downloads/Vanguard Lounge/1.5452.jpg (deflated 0%)
#   adding: content/downloads/Sunrise Library/ (stored 0%)
#   adding: content/downloads/Sunrise Library/1.stringio.jpg (deflated 1%)
#   adding: content/downloads/HardHat Lounge "Las Vegas"/ (stored 0%)
#   adding: content/downloads/HardHat Lounge "Las Vegas"/1.20161101_LVW_Hard_Hat_Lounge_LE2_t1000.jpg (deflated 0%)

# %%
files.download(output_zip)
# Out:
# ----------------------------------------
# Exception happened during processing of request from ('::ffff:127.0.0.1', 56480, 0, 0)
# Traceback (most recent call last):
#   File "/usr/lib/python3.6/socketserver.py", line 320, in _handle_request_noblock
#     self.process_request(request, client_address)
#   File "/usr/lib/python3.6/socketserver.py", line 351, in process_request
#     self.finish_request(request, client_address)
#   File "/usr/lib/python3.6/socketserver.py", line 364, in finish_request
#     self.RequestHandlerClass(request, client_address, self)
#   File "/usr/lib/python3.6/socketserver.py", line 724, in __init__
#     self.handle()
#   File "/usr/lib/python3.6/http/server.py", line 418, in handle
#     self.handle_one_request()
#   File "/usr/lib/python3.6/http/server.py", line 406, in handle_one_request
#     method()
#   File "/usr/lib/python3.6/http/server.py", line 639, in do_GET
#     self.copyfile(f, self.wfile)
#   File "/usr/lib/python3.6/http/server.py", line 800, in copyfile
#     shutil.copyfileobj(source, outputfile)
#   File "/usr/lib/python3.6/shutil.py", line 82, in copyfileobj
#     fdst.write(buf)
#   File "/usr/lib/python3.6/socketserver.py", line 803, in write
#     self._sock.sendall(b)
# ConnectionResetError: [Errno 104] Connection reset by peer
# ----------------------------------------
